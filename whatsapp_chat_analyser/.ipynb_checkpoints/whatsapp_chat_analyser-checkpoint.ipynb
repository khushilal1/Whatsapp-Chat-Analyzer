# %%
# regular expression

# %%
import re

# %%
# crick_score='''Sachin score 76 and Dravin score 40 and Rohit score 88 and Dhoni score 99'''
# print(crick_score)

# %% [markdown]
# # findall() function rerturn a list containing all matches

# %%
# name=re.findall(r'[A-Z][a-z]*',crick_score)
# print(name)

# %%
# age=re.findall(r'\d{2}',crick_score)
# print(age)

# %%
# crick_dash={}
# i=0
# for x in name:
#     crick_dash[x]=age[i]
#     i=i+1

# print(crick_dash)

# %%
#search() return a match object .if there is match it give 
# str='Her name is Tammana and Tammana is good girl'

# %%
# if re.search("Tammana",str):
#     print('item found')
#     match=re.findall('Tammana',str)
#     print(match)
#     for i in match:
#         print(i)

# %%
# FOR INDEX
# for i in re.finditer("Tammana",str):
#     index=i.span()
#     print(index)

# %%
# str1='Rat Cat Mat Sat Pat'
# data=re.findall(r'[RCMP]at',str1)
# print(data)

# %%
# #not 
# str1='Rat Cat Mat Sat Pat'
# data=re.findall(r'[^RCMP]at',str1)
# print(data)

# %%
# #not having starting with R--P
# str1='Rat Cat Mat Sat Pat'
# data=re.findall(r'[^P-R]at',str1)
# print(data)

# %%
# reg=re.compile('[R]at')
# print(reg)
# str1=reg.sub('Lion',str1)
# print(str1)

# %%
# str2=''''How are you?
# I am fine
# Thankyou
# '''
# print(str2)

# %%
# reg1=re.compile('\n')
# # print(reg1)
# str3=reg1.sub(' ',str2)
# print(str3)

# %%
# pattern='12aaaRR3456667890'
# print('no. of digits ',len(re.findall('\d',pattern)))
# print('no. of 6 occurance ',len(re.findall('\d{6}',pattern)))
# print('no. of alphabet ',len(re.findall('\D',pattern)))

# %%
# multinum='12 123 1234 12345 123456 1234567 12345678 123456789'
# print('no. of digits ',len(re.findall('\d{5,7}',multinum)))

# %%
#project started

# %%
import pandas as pd

import numpy as np


import re

# %%
f=open("WhatsApp_Chat_with_Guddu.txt",'r',encoding='utf-8')

# %%
data=f.read()

# %%
data
# Out:
# '28/09/2022, 9:21\u202fpm - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n28/09/2022, 8:23\u202fpm - Guddu...: Hlo\n28/09/2022, 9:43\u202fpm - Khushilal: Hjr\n28/09/2022, 9:43\u202fpm - Khushilal: Vannue\n28/09/2022, 9:43\u202fpm - Khushilal: S\n29/09/2022, 6:33\u202fam - Guddu...: ?\n29/09/2022, 11:36\u202fam - Guddu...: <Media omitted>\n29/09/2022, 11:37\u202fam - Guddu...: <Media omitted>\n29/09/2022, 11:37\u202fam - Guddu...: Kun phone ramro xa\n29/09/2022, 2:22\u202fpm - Khushilal: Kasko lagi\n29/09/2022, 2:22\u202fpm - Khushilal: Kinna lago\n29/09/2022, 2:41\u202fpm - Guddu...: This message was deleted\n29/09/2022, 2:41\u202fpm - Guddu...: Xito वन\n29/09/2022, 2:41\u202fpm - Guddu...: Vana\n29/09/2022, 2:42\u202fpm - Guddu...: Dashai मा नी कति busy hune garxau\n29/09/2022, 2:42\u202fpm - Khushilal: Ma configure gare vanxu la\n29/09/2022, 2:43\u202fpm - Khushilal: Yaha ek mahina dekhi mobli banda thyo ani ali sms garna pako xu so\n29/09/2022, 2:44\u202fpm - Guddu...: Kina\n29/09/2022, 2:44\u202fpm - Guddu...: Ka xau ra\n29/09/2022, 2:53\u202fpm - Khushilal: La on thw evaluation of the featuee and public review\n29/09/2022, 2:53\u202fpm - Khushilal: Real me be the best\n29/09/2022, 2:54\u202fpm - Guddu...: Aajha phone haru ko ni name vana na\n29/09/2022, 2:54\u202fpm - Guddu...: 14 to 18k ko range ra IC\n29/09/2022, 2:54\u202fpm - Khushilal: Ipjone leu ramro hunxa\n29/09/2022, 2:55\u202fpm - Khushilal: Tyaso vaye\n29/09/2022, 2:55\u202fpm - Guddu...: Lidi na\n29/09/2022, 2:56\u202fpm - Khushilal: Kasko lagi ho van ma tyaanusar herxu\n29/09/2022, 2:57\u202fpm - Guddu...: La mero lagi, aaba ramari hera aani vana\n29/09/2022, 2:59\u202fpm - Khushilal: Sachaii ho\n29/09/2022, 2:59\u202fpm - Guddu...: This message was deleted\n29/09/2022, 3:00\u202fpm - Guddu...: This message was deleted\n29/09/2022, 3:00\u202fpm - Guddu...: Umm k\n29/09/2022, 3:01\u202fpm - Khushilal: Redmi vadna real me ramro haii\n29/09/2022, 3:01\u202fpm - Guddu...: Aagadi send gare ko tik xa ni\n29/09/2022, 3:01\u202fpm - Guddu...: Natra real me mai aaru ni hera na\n29/09/2022, 3:04\u202fpm - Guddu...: <Media omitted>\n29/09/2022, 3:05\u202fpm - Guddu...: La yo dutai ma vandau ta\n29/09/2022, 3:08\u202fpm - Khushilal: Yo ani lasto ko ma euta leu\n29/09/2022, 3:16\u202fpm - Guddu...: Tai duta bata Aauta  select garna vane\n29/09/2022, 3:18\u202fpm - Guddu...: Quick charging hera ta\n29/09/2022, 3:19\u202fpm - Khushilal: Tyo ni maile nai garnu parne ho\n29/09/2022, 3:19\u202fpm - Guddu...: Gardau na k vayo\n29/09/2022, 3:19\u202fpm - Khushilal: Free maii\n29/09/2022, 3:20\u202fpm - Guddu...: Aani k chaiyoo🤣🤣\n29/09/2022, 3:22\u202fpm - Guddu...: K vayo\n29/09/2022, 3:24\u202fpm - Khushilal: Last ko thik xa\n29/09/2022, 3:24\u202fpm - Guddu...: Feature aautai here ma size thulo dutai ko compare ma\n29/09/2022, 3:25\u202fpm - Khushilal: Ali ali farak xa\n29/09/2022, 3:25\u202fpm - Guddu...: K xa aajha\n29/09/2022, 3:25\u202fpm - Khushilal: Euta 4g arko 5 g xa\n29/09/2022, 3:26\u202fpm - Guddu...: Umm tyo ni xa\n29/09/2022, 3:26\u202fpm - Guddu...: This message was deleted\n29/09/2022, 3:27\u202fpm - Guddu...: Thank u vandi na\n29/09/2022, 3:27\u202fpm - Khushilal: <Media omitted>\n29/09/2022, 3:27\u202fpm - Khushilal: <Media omitted>\n29/09/2022, 3:27\u202fpm - Khushilal: <Media omitted>\n29/09/2022, 3:27\u202fpm - Khushilal: <Media omitted>\n29/09/2022, 3:27\u202fpm - Khushilal: <Media omitted>\n29/09/2022, 3:28\u202fpm - Khushilal: K vayo vaneko thank you return hudai na\n29/09/2022, 3:28\u202fpm - Guddu...: Clear xaina kehi bujhi ra xaina\n29/09/2022, 3:29\u202fpm - Khushilal: J hos lasto wala thik xq tyati ho\n29/09/2022, 3:30\u202fpm - Guddu...: Seen garyo vane, return garnu parxa mero\n29/09/2022, 3:32\u202fpm - Khushilal: Kin retur mageko\n29/09/2022, 3:35\u202fpm - Khushilal: Kam vayesi ta repl nai banda hudo rahex haii \nSab manxe yastaii xa yo duniya jasto  ...

# %%
pattern = r'\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s*[apmAPM]{2}\s-\s'
message=re.split(pattern,data)[1:]
len(message)
# Out:
# 2012

# %%
date=re.findall(pattern,data)
len(date)
# Out:
# 2012

# %%
message_dict={'user_message':message,'message_date':date}
message_dict
# Out:
# {'user_message': ['Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n',
#   'Guddu...: Hlo\n',
#   'Khushilal: Hjr\n',
#   'Khushilal: Vannue\n',
#   'Khushilal: S\n',
#   'Guddu...: ?\n',
#   'Guddu...: <Media omitted>\n',
#   'Guddu...: <Media omitted>\n',
#   'Guddu...: Kun phone ramro xa\n',
#   'Khushilal: Kasko lagi\n',
#   'Khushilal: Kinna lago\n',
#   'Guddu...: This message was deleted\n',
#   'Guddu...: Xito वन\n',
#   'Guddu...: Vana\n',
#   'Guddu...: Dashai मा नी कति busy hune garxau\n',
#   'Khushilal: Ma configure gare vanxu la\n',
#   'Khushilal: Yaha ek mahina dekhi mobli banda thyo ani ali sms garna pako xu so\n',
#   'Guddu...: Kina\n',
#   'Guddu...: Ka xau ra\n',
#   'Khushilal: La on thw evaluation of the featuee and public review\n',
#   'Khushilal: Real me be the best\n',
#   'Guddu...: Aajha phone haru ko ni name vana na\n',
#   'Guddu...: 14 to 18k ko range ra IC\n',
#   'Khushilal: Ipjone leu ramro hunxa\n',
#   'Khushilal: Tyaso vaye\n',
#   'Guddu...: Lidi na\n',
#   'Khushilal: Kasko lagi ho van ma tyaanusar herxu\n',
#   'Guddu...: La mero lagi, aaba ramari hera aani vana\n',
#   'Khushilal: Sachaii ho\n',
#   'Guddu...: This message was deleted\n',
#   'Guddu...: This message was deleted\n',
#   'Guddu...: Umm k\n',
#   'Khushilal: Redmi vadna real me ramro haii\n',
#   'Guddu...: Aagadi send gare ko tik xa ni\n',
#   'Guddu...: Natra real me mai aaru ni hera na\n',
#   'Guddu...: <Media omitted>\n',
#   'Guddu...: La yo dutai ma vandau ta\n',
#   'Khushilal: Yo ani lasto ko ma euta leu\n',
#   'Guddu...: Tai duta bata Aauta  select garna vane\n',
#   'Guddu...: Quick charging hera ta\n',
#   'Khushilal: Tyo ni maile nai garnu parne ho\n',
#   'Guddu...: Gardau na k vayo\n',
#   'Khushilal: Free maii\n',
#   'Guddu...: Aani k chaiyoo🤣🤣\n',
#   'Guddu...: K vayo\n',
#   'Khushilal: Last ko thik xa\n',
#   'Guddu...: Feature aautai here ma size thulo dutai ko compare ma\n',
#   'Khushilal: Ali ali farak xa\n',
#   'Guddu...: K xa aajha\n',
#   'Khushilal: Euta 4g arko 5 g xa\n',
#   'Guddu...: Umm tyo ni xa\n',
#   'Guddu...: This message was deleted\n',
#   'Guddu...: Thank u vandi na\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: K vayo vaneko thank you return hudai na\n',
#   'Guddu...: Clear xaina kehi bujhi ra xaina\n',
#   'Khushilal: J hos lasto wala thik xq tyati ho\n',
#   'Guddu...: Seen garyo vane, return garnu parxa mero\n',
#   'Khushilal: Kin retur mageko\n',
#   'Khushilal: Kam vayesi ta repl nai banda hudo rahex haii \nSab manxe yastaii xa yo duniya jasto lago...\n',
#   'Guddu...: This message was deleted\n',
#   'Guddu...: Timi ka xau\n',
#   'Guddu...: Aaile\n',
#   'Guddu...: स्वार्थी भए  र\n',
#   'Khushilal: la 11 baje garam la kura la\n',
#   'Guddu...: This message was deleted\n',
#   'Guddu...: This message was deleted\n',
#   'Guddu...: K vayo ki a na de ko reply\n',
#   'Khushilal: Ho ra\n',
#   'Khushilal: Special hune bala sathi sang kura garthe\n',
#   'Guddu...: Ko xa ra\n',
#   'Khushilal: Xa ni koii\n',
#   'Khushilal: That confedential\n',
#   'Guddu...: Vana mildai na\n',
#   'Khushilal: Vanamla\n',
#   'Khushilal: Kin yau mobile\n',
#   'Guddu...: Xaina\n',
#   'Guddu...: Tasto tyo vane aaile kina vane ko\n',
#   'Guddu...: Aaba xito vani hal\n',
#   'Khushilal: Hllo\n',
#   'Guddu...: Hjr\n',
#   'Khushilal: Hloo\n',
#   'Khushilal: Voli kaha mela jane bchar xa\n',
#   'Guddu...: Ghar ma\n',
#   'Guddu...: Bidesh bata laiye ko phone lai darta garaunu parxa ki nai\n',
#   'Guddu...: Purnima heri heri reply dine manxe\n',
#   'Khushilal: Aja sayad feri purnima ho ki kaso\n',
#   'Guddu...: Tyo ta timi lai tha hunu parne\n',
#   'Khushilal: Ho aja ho\n',
#   'Guddu...: Tyo ta use gare lai tha hola ni\n',
#   'Khushilal: Reply didanua tme ani malai vanxa manxe chahi\n',
#   'Khushilal: Kasto duniya ayoo\n',
#   'Khushilal: Tyasko lagi check garnu para\n',
#   'Khushilal: Registre vako xa ki nai using imei number checking\n',
#   'Khushilal: Kaha vago ....\n',
#   'Guddu...: Dunya hoina, timi\n',
#   'Guddu...: Duniya lai kina dos dinxau\n',
#   'Guddu...: Bujhi na\n',
#   'Khushilal: Kaslai dos diu ta vanna\n',
#   'Guddu...: Kasari ,\n',
#   'Guddu...: Ka zau aaile\n',
#   'Guddu...: Xau\n',
#   'Guddu...: Aafai lai😂\n',
#   'Khushilal: Kasri\n',
#   'Guddu...: Tyo timi lai aafai tha hola\n',
#   'Khushilal: https://english.onlinekhabar.com/nta-implements-mdms.html\n',
#   'Khushilal: https://mdms.nta.gov.np/\n',
#   'Khushilal: Tala ko link ma gayer IMEI NO. HALNE\n',
#   'Khushilal: Ani k hudai xa aja kal\n',
#   'Guddu...: K na k😔\n',
#   'Khushilal: Bujhyauu\n',
#   'Khushilal: Mero vagya kharab xa\n',
#   'Khushilal: Bahut\n',
#   'Khushilal: https://www.facebook.com/827299590728284/posts/4298173676974174/\n',
#   'Khushilal: Yasma kunqi mandi foto send gara la\n',
#   'Guddu...: ??\n',
#   'Khushilal: Click gara anii thaha\n',
#   'Khushilal: Pauxauuu\n',
#   'Guddu...: Mandi?\n',
#   'Guddu...: ?\n',
#   'Guddu...: <Media omitted>\n',
#   'Khushilal: Tyo page ko form ma rakhna\n',
#   'Khushilal: https://www.facebook.com/827299590728284/posts/pfbid0y6HbToqFRTxVKnZYx7QPAiTvBUzxzbPbtwXVtEvSRFJCVRQudufnjaiXaNJR8gmil/?app=fbl\n',
#   'Khushilal: You deleted this message\n',
#   'Guddu...: K xa yo\n',
#   'Guddu...: null\n',
#   'Guddu...: Timi k ma parxau\n',
#   'Khushilal: K ma rakhxau tyasmai\n',
#   'Guddu...: Tasto ni hunxa🤣🤣\n',
#   'Guddu...: K ma xau, la vandau\n',
#   'Khushilal: K lagxa tme lai\n',
#   'Guddu...: Tha, na vaye ra sode, natra ka sodhu ma\n',
#   'Khushilal: Guess\n',
#   'Guddu...: Tasto kaam gardi na ma, la vandau\n',
#   'Khushilal: Ag\n',
#   'Guddu...: Kaile dekhi\n',
#   'Khushilal: Khoi\n',
#   'Khushilal: K xa giriraj ko khabar uta tir\n',
#   'Khushilal: Kaha harayau\n',
#   'Guddu...: Kata na kata\n',
#   'Khushilal: Kin k vo ra\n',
#   'Guddu...: <Media omitted>\n',
#   'Guddu...: <Media omitted>\n',
#   'Khushilal: Independent ko dekhayen\n',
#   'Guddu...: Competation 2 bich matra xa , independent tharai paxadi\n',
#   'Guddu...: Timro bichar ma ko jite ko ramro\n',
#   'Guddu...: Timi k ma vote diye tyo\n',
#   'Khushilal: Sabai afano vision ra agenda le ako hunxa aba heram\n\nKati baki x counting hune\n',
#   'Khushilal: And chitwan ko k xa update\n',
#   'Guddu...: Tha vaye na\n',
#   'Khushilal: Mero bicahr ma tme jiteko vaye ramro ni\n',
#   'Guddu...: Kina ni\n',
#   'Guddu...: Ma k gartye\n',
#   'Khushilal: Ma part Khan pauthe so\n',
#   'Khushilal: Ma birgunj janu parne xa\n',
#   'Guddu...: Lovi manxe\n',
#   'Guddu...: Kina\n',
#   'Khushilal: Vetnu xa ek jana lai\n',
#   'Guddu...: Kaslai\n',
#   'Khushilal: Xa\n',
#   'Guddu...: Ko\n',
#   'Guddu...: Vana mildai na\n',
#   'Khushilal: Nai\n',
#   'Guddu...: Ok\n',
#   'Khushilal: Vanamla\n',
#   'Khushilal: Suitable time ko wait gara\n',
#   'Guddu...: Vanu xa vane aaile vanA, natra tasto ma wait gare ra basne khal ki xuina\n',
#   'Khushilal: Ok n basa\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Khushilal: Hllo\n',
#   'Guddu...: Hjr\n',
#   'Khushilal: K xa khabar\n',
#   'Khushilal: Cll garu\n',
#   'Guddu...: Tik vanoo ki bekar tha xaina\n',
#   'Khushilal: Lekhna jhyau lagxa\n',
#   'Guddu...: Voli exam🥺🥺\n',
#   'Guddu...: Numerical gardau na\n',
#   'Khushilal: Call garxu la ahile 5min ta ho\n',
#   'Khushilal: Kun ko ho\n',
#   'Guddu...: Kehi bises xa ra\n',
#   'Guddu...: Genetic\n',
#   'Khushilal: Vanamla\n',
#   'Guddu...: La la 2 min\n',
#   'Guddu...: Sathi haru padhi ra xa disturb hunxa\n',
#   'Guddu...: Missed voice call\n',
#   'Khushilal: K vo ta\n',
#   'Khushilal: <Media omitted>\n',
#   'Guddu...: Thank u, buttimi lai kasari tha vayo ma patlu xu\n',
#   'Khushilal: <Media omitted>\n',
#   'Guddu...: Intelligent manxe\n',
#   'Guddu...: But ma motaxu\n',
#   'Khushilal: <Media omitted>\n',
#   'Guddu...: Juoo motaye si sound ni motaooxa ki kaso\n',
#   'Guddu...: Ma motaoodi na kaile\n',
#   'Guddu...: Jasto lagxa malai\n',
#   'Khushilal: La exam sakesi sms gara......\n',
#   'Khushilal: Ahile gaye\n',
#   'Guddu...: Huss\n',
#   'Khushilal: Guddu\n',
#   'Guddu...: https://fb.watch/irwJ0bFCIt/?mibextid=2Rb1fB\n',
#   'Khushilal: K ko link ho\n',
#   'Guddu...: Jasto lagi ra xa herekai xaina tastai\n',
#   'Khushilal: Yasto link haru na open gara hacker haru phone hack garidin sakxa\n',
#   'Khushilal: Sachaii dekhya xaiii\n',
#   'Guddu...: Sachai yasto hunxa\n',
#   'Guddu...: Hoina ma yo Facebook ko video ko link send gare ho\n',
#   'Guddu...: Exam haru ta xaina ni timro aaile\n',
#   'Khushilal: Tmro xa hoin\n',
#   'Khushilal: Exam\n',
#   'Khushilal: Padhne afu xau ani malai vanxau hyat\n',
#   'Guddu...: Xa\n',
#   'Guddu...: Na padhe ra ta sms gare ho\n',
#   'Guddu...: Ma\n',
#   'Khushilal: Kura garnu xa vane cll gara yo typing jhau lagxa haiii\n',
#   'Guddu...: Yati sama ko aalxi kaile dekhi\n',
#   'Khushilal: https://chat.openai.com/chat\n',
#   'Guddu...: <Media omitted>\n',
#   'Guddu...: <Media omitted>\n',
#   'Khushilal: https://chat.openai.com/chat\n',
#   'Guddu...: <Media omitted>\n',
#   'Khushilal: <Media omitted>\n',
#   'Guddu...: <Media omitted>\n',
#   'Khushilal: <Media omitted>\n',
#   'Guddu...: https://fb.watch/iu2QwJlpQ4/\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: kin pathako malai yo\n',
#   'Guddu...: Timi haru ko junior aai sake hola hsi\n',
#   'Guddu...: Pida buje ra🤣🤣\n',
#   'Guddu...: K ko tarkari ho\n',
#   'Guddu...: Kati oil khanxau\n',
#   'Khushilal: Bujha afaii\n',
#   'Khushilal: Kukhura\n',
#   'Khushilal: Dukha xa ni\n',
#   'Guddu...: Tai dukkha bujhe ra ta patha ko\n',
#   'Guddu...: Yasto vane lai forward gardinu\n',
#   'Khushilal: Yatika experince kasri vayauuu\n',
#   'Khushilal: Thanks dukha bujheko mq\n',
#   'Khushilal: Ya exam le ramri pelya xa ani k junior na senior\n',
#   'Guddu...: Sathi haru ko pida deke ra aafai\n',
#   'Guddu...: Mainly u\n',
#   'Khushilal: Tme malai k samjheko ma tyasto mnxe lagiraxu ra\n',
#   'Khushilal: Ra\n',
#   'Khushilal: Tyati samma ko kharab xuin oooo\n',
#   'Khushilal: Jati man lago tyati\n',
#   'Khushilal: hloo\n',
#   'Khushilal: kaha vagyau\n',
#   'Guddu...: Udi saki thye\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: <Media omitted>\n',
#   'Guddu...: Timi dance gari ra xau vane vhane, biswas vai ra xaina k\n',
#   'Guddu...: Tyo ni jab lagane lu jab libistk🤣🤣🤣\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: sachaii\n',
#   'Khushilal: tme lai jhuto lagya thyo\n',
#   'Guddu...: Umm\n',
#   'Khushilal: kasailai na pathaunu haii\n',
#   'Khushilal: la\n',
#   'Guddu...: Saraswati vagwan ko aagadi ma banner rakhe ra\n',
#   'Guddu...: Yasto yasto geet ma dance gardai\n',
#   'Guddu...: Ma ta pathai sake\n',
#   'Guddu...: Mero ma kehi send garna bitikai google ma save🤣🤣\n',
#   'Khushilal: arukai na pathaunu k bujhenau\n',
#   'Guddu...: Nai\n',
#   'Guddu...: Herna lai patha ho ni aani\n',
#   'Guddu...: Viral garaoonu pare na\n',
#   'Khushilal: tme lai herna lai pathako ni  aru lai hoin\n',
#   'Guddu...: Ok but malai viral garauna maan xa\n',
#   'Khushilal: malai viral hunu man xain\n',
#   'Guddu...: Nai , vai hala k\n',
#   'Khushilal: aru koi sang maile thaha paye vane ramro hudAIN N\n',
#   'Guddu...: Kina na ramro hunu\n',
#   'Guddu...: Sab ramrai vai ra xa\n',
#   'Guddu...: La la garaoodi na tension na lau\n',
#   'Guddu...: Baru sulai pathai dinxu hunxa\n',
#   'Khushilal: K VANYA\n',
#   'Khushilal: j kaun he fir sulai\n',
#   'Guddu...: Dhaga lai\n',
#   'Guddu...: Uslai ho k, typing mistake\n',
#   'Khushilal: kaslia\n',
#   'Guddu...: Tha nai hola Timi lai\n',
#   'Khushilal: xain sab birse\n',
#   'Guddu...: Ok\n',
#   'Guddu...: Then vandi na\n',
#   'Guddu...: La byee, malai vok lagi sakyo\n',
#   'Khushilal: malai ni lastaii vok lago\n',
#   'Guddu...: La khaoo\n',
#   'Khushilal: khana pako\n',
#   'Guddu...: Aadhi\n',
#   'Khushilal: kaslai tme bahek maile send gray xain tyo viddeo\n',
#   'Khushilal: vana k\n',
#   'Guddu...: Kati tiktok bani sake hola\n',
#   'Khushilal: call garxu la k k vanxau ma bujhin\n',
#   'Guddu...: Nai\n',
#   'Guddu...: Na gara\n',
#   'Khushilal: k ho tiktok ko kura\n',
#   'Guddu...: Aaba aarko din vanu la\n',
#   'Khushilal: la la\n',
#   'Khushilal: rose payau ta aja.....\n',
#   'Guddu...: Diye po paunu\n',
#   'Khushilal: Ma bg xu  9 baje paxi cll graxu\n',
#   'Guddu...: No, voli exam😟\n',
#   'Guddu...: <Media omitted>\n',
#   'Khushilal: Kate le ta tme dekher darayer pani na deko hola\n',
#   'Guddu...: Yasto ni hunxa ra,\n',
#   'Guddu...: Ma bata kina daraoonu paryo ra\n',
#   'Khushilal: <Media omitted>\n',
#   'Guddu...: Same to u🥰\n',
#   'Guddu...: But yo hamro culture hoina ni\n',
#   'Guddu...: Thank u\n',
#   'Khushilal: 🥱🥱🥱🥱\n',
#   'Khushilal: You deleted this message\n',
#   'Khushilal: Best of luck for today...\n',
#   'Khushilal: https://www.facebook.com/bhuvantiwarivines/videos/900287777841798/?app=fbl\n',
#   'Guddu...: Tasai\n',
#   'Guddu...: Umm\n',
#   'Khushilal: Send gara na\n',
#   'Guddu...: K\n',
#   'Khushilal: Hernai lagya the tme le unsent garyau\n',
#   'Guddu...: Here noo\n',
#   'Guddu...: This message was deleted\n',
#   'Khushilal: Kaha ser ko agadi ma yehi chuha haru aye xan\n',
#   'Khushilal: Gudiya as ser hai\n',
#   'Guddu...: Gudiya nai xu\n',
#   'Khushilal: Arko xain\n',
#   'Guddu...: Nai\n',
#   'Khushilal: Change vaxai nau\n',
#   'Guddu...: Nai\n',
#   'Guddu...: Timi lai kasto lagdai\n',
#   'Khushilal: Ali ali change vako xau\n',
#   'Khushilal: Jasto\n',
#   'Guddu...: <Media omitted>\n',
#   'Guddu...: Yo k xa vana\n',
#   'Khushilal: Ye ka he\n',
#   'Khushilal: Pata nahi\n',
#   'Khushilal: hat xa\n',
#   'Khushilal: name vana ta\n',
#   'Guddu...: Name vanu hudai na\n',
#   'Khushilal: Vana\n',
#   'Guddu...: Nai nai\n',
#   'Khushilal: Ma kehi vandin na ooo\n',
#   'Guddu...: No\n',
#   'Khushilal: Kasto na patyako\n',
#   'Guddu...: K ma na patya ko ha\n',
#   'Khushilal: Maile kehi vandin tyo\n',
#   'Guddu...: Name tha paye ra k garxau k\n',
#   'Khushilal: La padhna janau\n',
#   'Guddu...: Parsi exam xa biochemistry ko😢\n',
#   "Khushilal: Exam exam exam \n I don't like exam \nBut exam likes me \nI cant avoid exam.....\n",
#   'Khushilal: Dance\n',
#   'Guddu...: La la gara\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: Bachha\n',
#   'Guddu...: 73 ki 72 ko xa\n',
#   'Khushilal: Yo time ma dherrai innocent thiyau hoin\n',
#   'Khushilal: La padhna gaye aba la...\n',
#   'Guddu...: Khoi\n',
#   'Guddu...: But aaile ni tastai xu, jasto lagxa malai\n',
#   'Khushilal: Malai thaha a ni\n',
#   'Khushilal: Tme lai lager hudai na\n',
#   'Guddu...: Aani\n',
#   'Khushilal: Vanamla\n',
#   'Guddu...: Ok\n',
#   'Khushilal: Hllo\n',
#   'Guddu...: Vana\n',
#   'Khushilal: ..\n',
#   'Guddu...: This message was deleted\n',
#   'Khushilal: K unsent garya\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: Vana\n',
#   'Guddu...: K\n',
#   'Guddu...: Maile video here the yo\n',
#   'Khushilal: Pathau ta\n',
#   'Khushilal: ..\n',
#   'Guddu...: Yastai Facebook ma k\n',
#   'Guddu...: Timi jo screenshot gare xau\n',
#   'Guddu...: Vana vane ra rati nai vabe tye\n',
#   'Khushilal: K\n',
#   'Guddu...: Smiley saurabh ko xa🤣\n',
#   'Guddu...: ?\n',
#   'Khushilal: kin chahiyo\n',
#   'Guddu...: Name ramro lake xa\n',
#   'Khushilal: Tyatikaii\n',
#   'Guddu...: Tai vaye ra ta maile vabe tye vana vane ra\n',
#   'Khushilal: Pet pooja vayo\n',
#   'Guddu...: Aali aali sajh mai\n',
#   'Guddu...: Aajha baki nai xa🤣🤣\n',
#   'Guddu...: Timro ni\n',
#   'Khushilal: Vaisako\n',
#   'Guddu...: <Media omitted>\n',
#   'Guddu...: Kina yasto vayo tala ko seen mathi ko xaina\n',
#   'Khushilal: K vanished\n',
#   'Guddu...: Screenshot ma hera tha pauxau\n',
#   'Guddu...: Natra xordau\n',
#   'Guddu...: La makai khana ni pakaoonu xa\n',
#   'Khushilal: bujhin cll gru xito vana malai arko ni kam xw\n',
#   'Guddu...: Malai ni kaam xa\n',
#   'Guddu...: <Media omitted>\n',
#   'Khushilal: Tyatikai hola\n',
#   'Khushilal: Tyaso ni chinta liyer basya xay ra\n',
#   'Guddu...: https://fb.watch/iDnT6rTz_x/?mibextid=2Rb1fB\n',
#   'Guddu...: Voli exam aaile uo video herdai\n',
#   'Khushilal: Kin hereko ta padhdai vaigo ni ..yehi kam xa tmro\n',
#   'Guddu...: Khoi\n',
#   'Guddu...: Timi le nai garda\n',
#   'Guddu...: Timi sms gariyo, aani hath ma phone li na bitikai start\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: 📢📢\n',
#   'Khushilal: https://www.facebook.com/100044376341356/posts/pfbid02hMugvynVi5eKjEH4iEenbKTFhD5RY4SXoceQibjV2KvQvpNFLdYoJC2vVhs6hmnQl/?app=fbl\n',
#   'Guddu...: <Media omitted>\n',
#   'Khushilal: Tme le banako ho\n',
#   'Guddu...: Kasto xa\n',
#   'Khushilal: Yaslai vanna ta word ni vetin  maile\n',
#   'Guddu...: Kina ni\n',
#   'Khushilal: Super wala excellent xa\n',
#   'Guddu...: Sachai\n',
#   'Guddu...: Khana khayoo\n',
#   'Khushilal: Khuwaune manxe xain kasle khuwauxa\n',
#   'Khushilal: Voli ko plan k xa ta\n',
#   'Guddu...: Voli ko plan?\n',
#   'Khushilal: Voli bises day hoin\n',
#   'Guddu...: Field ma kaam garnu parne😂\n',
#   'Guddu...: Bises day k xa ra\n',
#   'Khushilal: Voli kun day ho ra?\n',
#   'Guddu...: Tuesday\n',
#   'Khushilal: Ramro tme le sunday Monday birsya xainau\n',
#   'Guddu...: Taso vye, Hotel jau na, serve garne le nai khuwai dinxa\n',
#   'Khushilal: Khaye afno kasto khabar\n',
#   'Guddu...: Bujhi na\n',
#   'Khushilal: Tme khanay khayau ki naj vanya\n',
#   'Guddu...: Baki xa\n',
#   'Guddu...: Aaba khane\n',
#   'Khushilal: Laz manxe haru\n',
#   'Guddu...: K\n',
#   'Khushilal: S\n',
#   'Khushilal: Lazy vanya\n',
#   'Guddu...: Kina ni\n',
#   'Guddu...: Lazy vanxau\n',
#   'Guddu...: This message was deleted\n',
#   'Guddu...: La kha na aau\n',
#   'Khushilal: Afaii le banayau\n',
#   'Khushilal: Damj banayau tara\n',
#   'Guddu...: Umm\n',
#   'Khushilal: Bato ma xu\n',
#   'Guddu...: Ok\n',
#   'Guddu...: Aaudai gara\n',
#   'Khushilal: https://www.facebook.com/DhruvRatheePage/videos/562991565852323/\n',
#   'Khushilal: https://www.facebook.com/groups/530813374553191/permalink/963260804641777/?app=fbl\n',
#   'Guddu...: K pathapoxau k yati timi\n',
#   'Guddu...: K ho\n',
#   'Khushilal: Kehi hoin\n',
#   'Khushilal: khoi\n',
#   'Khushilal: Anand\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Khushilal: K gareko ha\n',
#   'Khushilal: Exam chaldai xa ho\n',
#   'Guddu...: Nai\n',
#   'Khushilal: Ok\n',
#   'Khushilal: Khana khayau\n',
#   'Guddu...: Yati chado\n',
#   'Khushilal: Holi ma kaha hunxau .Ghar auna\n',
#   'Guddu...: Khoi\n',
#   'Khushilal: Ma aisakya xu\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: Kin security change vako dekhauxa\n',
#   'Khushilal: Code\n',
#   'Guddu...: Khoi\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Khushilal: Sachaii\n',
#   'Khushilal: Can i call u today\n',
#   'Khushilal: https://youtu.be/K1GUpSHbAwA\n',
#   'Khushilal: For past one\n',
#   'Khushilal: https://www.facebook.com/100050919156982/posts/pfbid02z4wYSTQ3KoRT8P2hYtkisHnDb4J6kWxUzUcDEwX2Eh5tV9gcKSB86DJ67F4utp4tl/?app=fbl\n',
#   'Guddu...: 🤣🤣🤣🤣😃😃\n',
#   'Guddu...: Sachai🤣\n',
#   'Khushilal: khoi\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: happy holi\n',
#   'Guddu...: Engineer ko purai rup dhali sake xau ta🤣🤣🤣🤣\n',
#   'Guddu...: Kati le kapal batdi ra hola hai tha🤣🤣\n',
#   'Guddu...: Same to u\n',
#   'Khushilal: K vanya\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: Tme haru holi khelenau\n',
#   'Guddu...: 1 ,2% 🤣\n',
#   'Khushilal: matrai kin ra\n',
#   'Guddu...: Maan nai tatikai lagyo aani k garne\n',
#   'Khushilal: Sahi ho\n',
#   'Khushilal: photo heram na\n',
#   'Guddu...: Kasko\n',
#   'Khushilal: Holi kheleko\n',
#   'Guddu...: Aauta pani pic click gare xaina\n',
#   'Khushilal: <Media omitted>\n',
#   'Guddu...: Kasari timi aaba Biswas garxau k?\n',
#   'Khushilal: Aur sab batau kasto xa khabar\n',
#   'Khushilal: https://www.facebook.com/114055314517986/posts/pfbid02Y9tUzRwFvhM8aPDWGJzEAFQTbsShAh8oc6AapV7jR4B1qsRTB7vAYXcuX4Suq6xHl/?app=fbl\n',
#   'Khushilal: Yasto ni hune grxa ho\n',
#   'Khushilal: Raa\n',
#   'Khushilal: https://www.facebook.com/100065241650321/posts/pfbid02253EnspF3dPxWp7teJwoNHyEn9T2UPT6bR4HWqJgHJttNU1eP1ttykmMcQ2a9DH4l/\n',
#   'Khushilal: Wish gardeu haiii\n',
#   'Khushilal: <Media omitted>\n',
#   'Guddu...: Ghar ma xu\n',
#   'Guddu...: Fever\n',
#   'Guddu...: Ruga lage ra\n',
#   'Khushilal: Kahile ghar ayau ra\n',
#   'Khushilal: Sachaii\n',
#   'Guddu...: 19 kai\n',
#   'Guddu...: Umm, k ma jhuto bolxu yasto kura ma pani😥😥\n',
#   'Khushilal: Ahile samma niko bhako xaij raaa\n',
#   'Guddu...: Hoina , ruga lage ko varkhar 2 days dekhi\n',
#   'Khushilal: Aa ani ghar kin ayau xutti vako ho raa\n',
#   'Guddu...: Bida nai xa 1 months dekhi, aaba kaile exam ko routine aauxa\n',
#   'Khushilal: Ooo thik xa vote hunxa ki nai tyaha\n',
#   'Guddu...: K ko\n',
#   'Khushilal: freedom student union ..purai nepal ma xa\n',
#   'Guddu...: Ye\n',
#   'Guddu...: Umm\n',
#   'Khushilal: Sarkari cllg ma hunxa\n',
#   'Khushilal: Aru sab thik xa no\n',
#   'Khushilal: Bj\n',
#   'Khushilal: Bi\n',
#   'Khushilal: Ni\n',
#   'Guddu...: K ko yati hatar xa k\n',
#   'Khushilal: Kahile jane chitwan\n',
#   'Khushilal: Chunab ko\n',
#   'Guddu...: Katai na jane aaba\n',
#   'Guddu...: Ghar mai basne\n',
#   'Khushilal: Ki bhoj khuwaune bichar hudai xain  ni\n',
#   'Guddu...: Umm, pakaoo khauu\n',
#   'Khushilal: Specail wala\n',
#   'Guddu...: Kasto special bala ni\n',
#   'Khushilal: Xod exam paxi kura garamla\n',
#   'Guddu...: Kasko exam\n',
#   'Guddu...: Paxi\n',
#   'Khushilal: Dubai ko\n',
#   'Guddu...: Kaile dekhi xa ra\n',
#   'Khushilal: 17 To 12\n',
#   'Guddu...: Kun semester ko\n',
#   'Khushilal: Cll garam\n',
#   'Guddu...: Total kati ota sub\n',
#   'Khushilal: Jhau lago typing garna\n',
#   'Guddu...: Ruga lage ra nose bata sound aauxa🤣🤣\n',
#   'Khushilal: K hunxa ra\n',
#   'Guddu...: La la\n',
#   'Guddu...: Misscall paisa katxa ra timro\n',
#   'Khushilal: Kata vagyau\n',
#   'Khushilal: Data leu\n',
#   'Khushilal: Na tyaso vaye\n',
#   'Khushilal: Net slow xa vane\n',
#   'Guddu...: https://vt.tiktok.com/ZS84Wthg4/\n',
#   'Guddu...: Nai\n',
#   'Guddu...: Paisa xaina phone ma\n',
#   'Khushilal: Kin\n',
#   'Khushilal: Mobile no. Vana ta\n',
#   'Guddu...: Aani aaba sutnu ni xa\n',
#   'Guddu...: Nai\n',
#   'Khushilal: Ma data pack kinidinxu\n',
#   'Khushilal: Kun mobile no. Ho vana fa\n',
#   'Guddu...: Transfer garnu Pardai na xordau\n',
#   'Khushilal: Ta\n',
#   'Guddu...: Tablet khaye ra nindra lagdai xa\n',
#   'Khushilal: Yahi bat kinn milxa ta\n',
#   'Guddu...: Nai k\n',
#   'Khushilal: Yaspaxi jestha ma matrai kura hune ho\n',
#   'Khushilal: So vanya\n',
#   'Guddu...: Padhandas\n',
#   'Khushilal: Exam xa so vanya\n',
#   'Guddu...: Tauko pain vai ra xa\n',
#   'Khushilal: Hami engineer lai yastai ho\n',
#   'Guddu...: Baishak 12 samaatra xa ni\n',
#   'Khushilal: Kura gram video cll ani niko hujxa\n',
#   'Khushilal: Feri arko exam xa\n',
#   'Guddu...: La taso vaye dau\n',
#   'Guddu...: Ma sute\n',
#   'Khushilal: Hami engineer bytha aru lai k tha\n',
#   'Guddu...: Tauko poli ra xa yaha😥😥\n',
#   'Khushilal: Poll dai na manxe ni kasta xan\n',
#   'Khushilal: No. Deu na\n',
#   'Khushilal: Ekxin kura garer xodne ho\n',
#   'Guddu...: Voli\n',
#   'Khushilal: Today is last time ho\n',
#   'Khushilal: Sachaiiii\n',
#   'Guddu...: Kina ma voli nai ma yo earth xodxu rA\n',
#   'Guddu...: La padha\n',
#   'Khushilal: Voli sajh tir sms gara la time vako bela ...ghar ma huda garhai hunxa..??\n',
#   'Khushilal: Hellooo\n',
#   'Guddu...: Hjr\n',
#   'Guddu...: Kaha harayoo\n',
#   'Khushilal: Call garam la\n',
#   'Guddu...: La la\n',
#   'Guddu...: K vayo ra\n',
#   'Khushilal: Nai kehi xain vako tyatikai kura garna man garer matrai\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Khushilal: Hllo\n',
#   'Guddu...: Hii\n',
#   'Khushilal: K xa khabar\n',
#   'Khushilal: Exam xa tme haru ko ki sako\n',
#   'Guddu...: Na sodha\n',
#   'Guddu...: Dimag kharab\n',
#   'Khushilal: Exam hudai ho\n',
#   'Khushilal: Yastaii ho jindage\n',
#   'Khushilal: Exam vairaheko ho\n',
#   'Guddu...: Ho k\n',
#   'Khushilal: La padha tyaso vaye aram le haiiii\n',
#   'Khushilal: Top gara ani party deu\n',
#   'Guddu...: Yaha yasto ghumaye ra pagal jasto questions sodxa\U0001f979\n',
#   'Guddu...: Padhaone jama 4,5 din\n',
#   'Khushilal: Call garam hunxa dheraisepression ma gayau jasto xa\n',
#   'Khushilal: la ok padhaaaaa\n',
#   'Khushilal: Guddu\n',
#   'Guddu...: This message was deleted\n',
#   'Guddu...: Ko xa guddu\n',
#   'Khushilal: 🥱🥱\n',
#   'Guddu...: Hlo\n',
#   'Guddu...: Timro exam sakyo\n',
#   'Guddu...: ?\n',
#   'Khushilal: G\n',
#   'Khushilal: You deleted this message\n',
#   'Guddu...: This message was deleted\n',
#   'Guddu...: Vaye\n',
#   'Khushilal: Kin pagal vayau\n',
#   'Guddu...: This message was deleted\n',
#   'Guddu...: K gardai xau\n',
#   'Guddu...: Room Mai cau?\n',
#   'Guddu...: Xau\n',
#   'Khushilal: Ha\n',
#   'Khushilal: Room mai xu vana na\n',
#   'Guddu...: Kehi nai\n',
#   'Khushilal: Vana k vanna lagyau\n',
#   'Khushilal: Exam sakyo vane party deu na ta\n',
#   'Guddu...: This message was deleted\n',
#   'Guddu...: xaina\n',
#   'Guddu...: Phone gara\n',
#   'Guddu...: This message was deleted\n',
#   'Khushilal: Morning vaisko 🥱🥱\n',
#   'Guddu...: Nai\n',
#   'Khushilal: https://www.facebook.com/musicloversnepal/videos/786914929297996/\n',
#   'Khushilal: Kux alag laga sun kar\n',
#   'Guddu...: K xa ra\n',
#   'Khushilal: https://www.facebook.com/266674580893290/posts/pfbid0faY2Bhp2NDRRoRmLn1tFfuBatWWxB3fP6cDWvjVWDcUzgA6y6ctgt6iSo9x5ii23l/\n',
#   'Khushilal: Motivation\n',
#   'Khushilal: something\n',
#   'Khushilal: https://www.facebook.com/CapitalJanakpurOfficial/videos/3544041855817295/?app=fbl\n',
#   'Khushilal: Ysto pani hunx ra...\n',
#   'Guddu...: Khoi\n',
#   'Guddu...: Tha vaye na\n',
#   'Guddu...: Missed voice call\n',
#   'Khushilal: Vanna grya thyo...\n',
#   'Khushilal: Hllo\n',
#   'Khushilal: Kaha kho gaiiiii\n',
#   'Guddu...: Jaha khone chaiye\n',
#   'Khushilal: Call to kiya tha lekin kux nahi kaha\n',
#   'Guddu...: Mistak se hochuka tha\n',
#   'Khushilal: Ok thik ...badh bat karte he\n',
#   'Khushilal: Hllooo\n',
#   'Khushilal: Kaha xau ahile\n',
#   'Guddu...: Kina\n',
#   'Guddu...: Ghar ma\n',
#   'Your security code with Guddu... changed. Tap to learn more.\n',
#   'Khushilal: https://medium.com/@mahatokhushilal2019/big-data-as-advanced-one-fb992100a62?source=friends_link&sk=ac31ce152dd1db977c045e26831142eb\n',
#   'Khushilal: Yasma follow gardeu la\n',
#   'Guddu...: Huss\n',
#   'Khushilal: Padhnu man xa vane padh time lagayer lekheko xu tara\n',
#   'Guddu...: Ok\n',
#   'Guddu...: Aauta kura sodhoo\n',
#   'Guddu...: Mobile banking kasari login garne old bata new ma\n',
#   'Khushilal: https://youtu.be/bSu24H57050\n',
#   'Khushilal: Hera yasma vanya tyasari gara vaihalxa\n',
#   'Guddu...: <Media omitted>\n',
#   'Khushilal: siddhartha bank ko mobile app ma mobile no. Ra passwor rakher activate gara na ta\n',
#   'Guddu...: Vai ra xaina\n',
#   'Guddu...: <Media omitted>\n',
#   'Khushilal: Aurhotize gare ni vairaheko xain\n',
#   'Guddu...: Nai\n',
#   'Guddu...: <Media omitted>\n',
#   'Guddu...: <Media omitted>\n',
#   'Guddu...: Yastai vai ra xa\n',
#   'Khushilal: Bank jau tyso vaye dherai try garer navairaheko hola\n',
#   'Khushilal: Khoi follow garya\n',
#   'Guddu...: 8 followers matra xa\n',
#   'Khushilal: 3 din agadi dekhi writing suru gareko xu ani aru lai ni follow  garau la\n',
#   'Khushilal: thanks\n',
#   'Khushilal: Solved vayo hola\n',
#   'Guddu...: Nai\n',
#   'Guddu...: Bank nai ga xaina\n',
#   'Khushilal: Ramro tyaso vaye\n',
#   'Guddu...: Kina ni\n',
#   'Khushilal: Khoi\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: K ko bui xa\n',
#   'Guddu...: Yatro din paxi yad aako, sodhnu parne vhane ra😂😂\n',
#   'Khushilal: Khoii kasri yad ayo\n',
#   'Guddu...: Search\n',
#   'Guddu...: Gara\n',
#   'Khushilal: Name thaha vaye po search garneni\n',
#   'Guddu...: Scan gara na\n',
#   'Guddu...: phafar\n',
#   'Khushilal: Tmro tyatibforo hat scan vairaheko xain\n',
#   'Khushilal: Fohor\n',
#   'Guddu...: <Media omitted>\n',
#   'Khushilal: Good goggler\n',
#   'Guddu...: Timro phone kharab vaye ra mero hath lai dos didai\n',
#   'Guddu...: Pap lagxa🤣🤣🤣\n',
#   'Khushilal: Hat mai kharabi xa dherai bacteria vayer\n',
#   'Khushilal: Lagdai na\n',
#   'Khushilal: Lage vane dhoi halxu\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: kux alag  laga\n',
#   'Guddu...: Umm\n',
#   'Khushilal: Sach me\n',
#   'Khushilal: Bahut dino k bad\n',
#   'Guddu...: K\n',
#   'Khushilal: Bahut kux\n',
#   'Guddu...: Hlo\n',
#   'Khushilal: ha\n',
#   'Khushilal: Boliye madan\n',
#   'Khushilal: Madam\n',
#   'Guddu...: Busy xau\n',
#   'Guddu...: ?\n',
#   'Khushilal: Kahiye\n',
#   'Guddu...: ?\n',
#   'Khushilal: Kui yad kiya aja\n',
#   'Guddu...: Kam le nai\n',
#   'Khushilal: Kya kam he hamse\n',
#   'Khushilal: Boliye\n',
#   'Guddu...: Ipo varxau hola\n',
#   'Guddu...: Crn kasari tha paune\n',
#   'Guddu...: No. *\n',
#   'Khushilal: Ap vi kabse ipo varne lage\n',
#   'Khushilal: Bahut paisa ho gaya\n',
#   'Guddu...: 2 yrs aagadi vare tye, taile dekhi banda tyo\n',
#   'Guddu...: Hiso active gare, but crn no. Magdai\n',
#   'Guddu...: Aagadi username ra password le pugtyo\n',
#   'Khushilal: axa madam ji apka ki si vi mobile hya\n',
#   'Khushilal: To usme check karasakte\n',
#   'Khushilal: Nahi apa vank jakar le sakte he\n',
#   'Khushilal: Aur kux chahiye apko to batai madam ji\n',
#   'Guddu...: Gardau\n',
#   'Khushilal: Mobile banking\n',
#   'Khushilal: Kya\n',
#   'Guddu...: Umm\n',
#   'Guddu...: Crn no. Find out gardau\n',
#   'Guddu...: Busy xau ?\n',
#   'Khushilal: Kun bank ka mobile banking he apaka\n',
#   'Khushilal: Mero share ma login xain ki xau\n',
#   'Guddu...: Siddharth\n',
#   'Guddu...: K vhako ho manxe lai aaj, khub hindi\n',
#   'Guddu...: Xa\n',
#   'Guddu...: Paila crn no. Ta chai ra tye na\n',
#   'Khushilal: https://easybank.siddharthabank.com/crnview/crnviewcreate\n',
#   'Khushilal: Is link par jaiye aur apan dettail fill kijiye\n',
#   'Khushilal: Aur crn no. Paiye\n',
#   'Khushilal: Paya ki nai jawaf dijiye\n',
#   'Khushilal: boliye to ham kahi jana he\n',
#   'Khushilal: Kavi kavi\n',
#   'Guddu...: Kaha pe\n',
#   'Guddu...: Umm\n',
#   'Khushilal: Kahi\n',
#   'Guddu...: Matlab\n',
#   'Khushilal: Apaka problem solve huwa\n',
#   'Khushilal: Paty to banta he\n',
#   'Khushilal: Hame magna nahi chahya the apa jaisa lovi admi se\n',
#   'Guddu...: La La aau\n',
#   'Khushilal: Apana kam banta vare jai janta\n',
#   'Guddu...: Janta nai, engineer ji\n',
#   'Khushilal: Thik he madam ji apa moj kijiye .aur chahiye to batana thik he\n',
#   'Khushilal: Kitne ipo apko pargaya akhana tak\n',
#   'Guddu...: Dhanybaad\n',
#   'Guddu...: 2 yrs se bandi tha\n',
#   'Khushilal: Ki bat k liye\n',
#   'Guddu...: Total 6 tho vare tye, usme se jama 1\n',
#   'Khushilal: Aba parega ..mahr wan ki jiye ipo varna to ham chahte lekin paisa nahi he ..\n',
#   'Guddu...: Help karne k liye\n',
#   'Khushilal: Itne paisa madam to khub amir hai\n',
#   'Guddu...: Yasai easy tarika  YouTube me vi nahi paye\n',
#   'Guddu...: Sapna me\n',
#   'Guddu...: Kavi kavi\n',
#   'Guddu...: Aapko kitna tho para hai\n',
#   'Khushilal: Ham saral admi he aur hamara tarika aur saral\n',
#   'Khushilal: Ham to ipo vara hi nahi he\n',
#   'Guddu...: Jhuta, engineer sab vi jhut bolta hai oo to mujhe aavi tha huwa\n',
#   'Khushilal: Ham jhut nahi bolte e\n',
#   'Khushilal: He\n',
#   'Khushilal: Apa kaha par he avi madam ji\n',
#   'Guddu...: Ye ho nahi sakta, yaise bolte huye ham biswas nahi kar sakta\n',
#   'Khushilal: Kui\n',
#   'Guddu...: Ghar pe\n',
#   'Khushilal: Kab Chitwan jana he\n',
#   'Guddu...: Nahi jayenge\n',
#   'Khushilal: Kitne ghar baithe baithe motana hereditary\n',
#   'Khushilal: Kuin\n',
#   'Guddu...: Ooisahe\n',
#   'Guddu...: Aapka to kaam tha na bahar ka, fer aab kya huwa\n',
#   'Khushilal: Dhup k karan cancel kardiya\n',
#   'Khushilal: You deleted this message\n',
#   'Khushilal: Thik apa soja ooo\n',
#   'Khushilal: god\n',
#   'Khushilal: good\n',
#   'Khushilal: Hlo madam ji\n',
#   'Khushilal: Madam ji kuin gusa kar raheho\n',
#   'Khushilal: Oo madam ji\n',
#   'Guddu...: Voli kura garxu la\n',
#   'Khushilal: Nagarda ni hunxa\n',
#   'Guddu...: Kina ra k vayo\n',
#   'Guddu...: Na risaoo\n',
#   'Khushilal: Hamne apko sms kar ke disturb kiya isliye muze maf kijiye .madam\n',
#   'Guddu...: Xaina yasto kehi\n',
#   'Guddu...: Kasto socha yo manxe\n',
#   'Khushilal: Jaisa apka laga oisa\n',
#   'Khushilal: 🥱🥱🥱\n',
#   'Guddu...: 😥😥😥😥😢\n',
#   'Khushilal: 😇😇😇😇😇😇😇😇\n',
#   'Guddu...: Vana\n',
#   'Khushilal: K\n',
#   'Guddu...: Kehi nai\n',
#   'Khushilal: Call garxu la\n',
#   'Guddu...: Nai sms nai gara 😥😥\n',
#   'Khushilal: axa kaha xau ra\n',
#   'Khushilal: aur sab batau\n',
#   'Khushilal: kahile kahi bolna pani kati kicha gareko vanya\n',
#   'Guddu...: Ghar ma\n',
#   'Guddu...: K vanu🥺😥😥\n',
#   'Khushilal: Axa\n',
#   'Khushilal: Ramro ya kharab\n',
#   'Khushilal: Madam kya ho raha he\n',
#   'Guddu...: Bahut bura hal\n',
#   'Guddu...: Sir ji, aapna vi batayee\n',
#   'Khushilal: Kui kya huwa jo\n',
#   'Guddu...: ?\n',
#   'Guddu...: <Media omitted>\n',
#   'Khushilal: Ye kya he fir\n',
#   'Khushilal: Hllo mam ji\n',
#   'Guddu...: Umm, batayai sir ji🙏, kya hal chal\n',
#   'Khushilal: app log to mahag hogaye ..haa logo ko kaun puxtehe .\n',
#   'Guddu...: Aap log, me kon kon parta hai, jara hame vhi bata do\n',
#   'Khushilal: Hame bahek aur sab\n',
#   'Khushilal: Ap to bikul parna chahiye ....\n',
#   'Guddu...: Aaisa mat bolye\n',
#   'Guddu...: https://fb.watch/lLZfDpFa95/?mibextid=VhDh1V\n',
#   'Khushilal: Kux viii???\n',
#   'Khushilal: बर्षाको पानी अलि पनि थाहा थिएन, तिम्रो मुस्कानले दिनमा सुन्दर गर्थिएन।\nहरेक बर्षाले तिमीलाई याद गर्छु मैं, तिम्रो हर्षले मेरो मन धुनिरहन्थ्यो अघिमा।\nअहिले जब बर्षा हुन्छ र तिमी छैनौ, तिम्रो यादले मलाई आँसु आएको छ।\nबर्षाको बूँद थियो तिम्रो हातमा, अहिले बर्षाको बूँदले मलाई रोकेको छ।\nतिम्रो गायनले मलाई रमाउँथ्यो मैले, तिम्रो हास्यले मलाई चिडाउँथ्यो मैले।\nबर्षाले चुमेको थियो मेरो चेलो तिम्रो, हरेक बर्षामा तिमी मेरो मनमा रहन्थ्यो।\nतिम्रो गर्वले छायाँ फैलाएको थियो आघामै, बर्षाले मलाई तिम्रो साथ छुटेको थियो आघामै।\nबर्षाको पानीमा तिम्रो यादले बहेको छ, तिम्रो मायाले मलाई हरेक बर्षामा चुमेको छ।\n\n\nyad yad bas yad rahjati he\n',
#   'Guddu...: Writer ✍️?\n',
#   'Khushilal: Thanku\n',
#   'Guddu...: Kasle lekhe xa\n',
#   'Khushilal: Khoi\n',
#   'Guddu...: Tha pai sake\n',
#   'Khushilal: Vana\n',
#   'Guddu...: Vanu pardai na\n',
#   'Guddu...: Send gardu\n',
#   'Guddu...: ?\n',
#   'Khushilal: Ha\n',
#   'Guddu...: Kaslai\n',
#   'Khushilal: Vana\n',
#   'Guddu...: La reply, kaslai soche ra diyoo ni\n',
#   'Khushilal: Khoi\n',
#   'Khushilal: Nothing auu kin serious vako .. tyo biteko kura yad ayo ani lekhe .tme reveiw gardeu kasto xa\n',
#   'Guddu...: Ma ka serious leko, tai ta ma ni vana khoje ko\n',
#   'Guddu...: Jasko yad aayo taslai forward gardiyo ?\n',
#   'Khushilal: gardiyee\n',
#   'Guddu...: ?\n',
#   'Khushilal: ..\n',
#   'Guddu...: Gari sakyo?\n',
#   'Khushilal: ..\n',
#   'Guddu...: Kehi nai\n',
#   'Guddu...: Xoradau\n',
#   'Khushilal: Vannu man xa vane vandeu navaye ?\n',
#   'Guddu...: Xaina\n',
#   'Guddu...: 1 baje tira bolxu\n',
#   'Khushilal: You deleted this message\n',
#   'Khushilal: Jo hukum\n',
#   'Guddu...: Huss\n',
#   'Guddu...: Voli phone garxu la\n',
#   'Guddu...: 12 baje tira\n',
#   'Khushilal: Apka jaisa ikxya....\n',
#   'Khushilal: Rati\n',
#   'Khushilal: Kaise he\n',
#   'Khushilal: Guffadi\n',
#   'Guddu...: Tik hu\n',
#   'Guddu...: Aapna batayai\n',
#   'Khushilal: Axa\n',
#   'Guddu...: Voli aakai xaina\n',
#   'Khushilal: Maha guffadi vayex manxe\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: Itna khus\n',
#   'Guddu...: Mat bol ye aaisa\n',
#   'Khushilal: Kabse\n',
#   'Khushilal: Kaha k photo he ye\n',
#   'Guddu...: 1 yrs se bahut dukh\n',
#   'Guddu...: Kaha ka lag raha hai,  guess kijiye\n',
#   'Khushilal: Ye kab ka hebjo\n',
#   'Khushilal: Pahad ka hoga\n',
#   'Khushilal: Jaisa lagraha he\n',
#   'Guddu...: Padhad to padhad hi hai\n',
#   'Khushilal: mera guess mila ki nahi\n',
#   'Khushilal: result aha chuka he ki nai\n',
#   'Khushilal: lagta he mam ji bahurt bg\n',
#   'Khushilal: to ham ne disturb to nahi kiya\n',
#   'Guddu...: Medicine khana latye\n',
#   'Guddu...: Kis chij ka\n',
#   'Khushilal: kya hone laga madam ko\n',
#   'Khushilal: khux galata to nahi hiwa na\n',
#   'Guddu...: Pata nahi, bahut jalda upar se bolaba hai\n',
#   'Khushilal: exam ka\n',
#   'Khushilal: kab ka plan he\n',
#   'Guddu...: Oo to aavi, pata nahi hai exact\n',
#   'Guddu...: Pata chale ga to batadunga\n',
#   'Khushilal: kis bat ka medicine\n',
#   'Guddu...: Nai, but kuch din me aane bala hai\n',
#   'Khushilal: moz kijoye\n',
#   'Guddu...: Kis khusi me\n',
#   'Guddu...: Aaj to hamlok bahut mooj kiya\n',
#   'Khushilal: bahut din me result ane wali he\n',
#   'Guddu...: Aab karugi to over hojaye ga\n',
#   'Khushilal: thora  matre kijiye\n',
#   'Khushilal: aur sab bataye kaise chal raha he jindagi\n',
#   'Guddu...: Jindagi, mat puchye\n',
#   'Guddu...: Buchna hi hai to din puchye\n',
#   'Khushilal: kuin kux problem ki kaisa\n',
#   'Guddu...: Ham nahi samjhe\n',
#   'Khushilal: problem share se halka hota he\n',
#   'Guddu...: Ooisa to kuch khas problem nahi hai\n',
#   'Khushilal: ki  koi paressan to nahi kar raha he\n',
#   'Guddu...: Jo ham aap ko bataye\n',
#   'Khushilal: apa bata sakte ho  agar problem he to\n',
#   'Guddu...: Ooisa, hohi nahi sakta, paresan karne bale ko dar nahi hai\n',
#   'Khushilal: aisa mat boliye\n',
#   'Khushilal: ho sakta he na\n',
#   'Khushilal: apne kaha khaliya he ki nahi\n',
#   'Guddu...: La byee\n',
#   'Guddu...: Ma sutna lage hai\n',
#   'Khushilal: ye to galat he\n',
#   'Khushilal: kahto ki 12 baje cal karta hu apa sona lage\n',
#   'Khushilal: ye anayaye he\n',
#   'Khushilal: ham ek sabal kare\n',
#   'Guddu...: Kya\n',
#   'Guddu...: Yatna rat k kon sabal puchta hai kya\n',
#   'Khushilal: so jayo\n',
#   'Khushilal: kux nahi bad me milte he\n',
#   'Guddu...: Missed voice call\n',
#   'Guddu...: Missed voice call\n',
#   'Khushilal: You deleted this message\n',
#   'Khushilal: Ha kahiye mam ji apne call kiya tha\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: You deleted this message\n',
#   'Khushilal: https://youtu.be/cNzp0PQ3YLQ\n',
#   'Khushilal: ..\n',
#   'Khushilal: Ashik aja call gara haiii\n',
#   'Khushilal: Kya aja bat kar sakte he???\n',
#   'Guddu...: No\n',
#   'Guddu...: Thora busy hu, Sunday ka\n',
#   'Khushilal: Avi kis me busy he\n',
#   'Khushilal: Kon san aisa kam he\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: Kux aram laga sun lar\n',
#   'Khushilal: Hi?\n',
#   'Guddu...: Hjr\n',
#   'Khushilal: Yasto gumnam vaidune ha manxe??\n',
#   'Guddu...: Bujhi na\n',
#   'Guddu...: Missed voice call\n',
#   'Guddu...: Kata harayoo\n',
#   'Khushilal: <Media omitted>\n',
#   'Khushilal: https://bard.google.com/\n',
#   'Khushilal: Yo duniya ni kati matlabi???\n',
#   'Guddu...: K vayo ra\n',
#   'Guddu...: Checkup garayoo\n',
#   'Khushilal: Nashod\n',
#   'Guddu...: K vayo\n',
#   'Guddu...: Missed voice call\n',
#   'Guddu...: Missed voice call\n',
#   'Guddu...: <Media omitted>\n',
#   'Guddu...: <Media omitted>\n',
#   'Khushilal: <Media omitted>\n',
#   'Guddu...: Vayo\n',
#   ...],
#  'message_date': ['28/09/2022, 9:21\u202fpm - ',
#   '28/09/2022, 8:23\u202fpm - ',
#   '28/09/2022, 9:43\u202fpm - ',
#   '28/09/2022, 9:43\u202fpm - ',
#   '28/09/2022, 9:43\u202fpm - ',
#   '29/09/2022, 6:33\u202fam - ',
#   '29/09/2022, 11:36\u202fam - ',
#   '29/09/2022, 11:37\u202fam - ',
#   '29/09/2022, 11:37\u202fam - ',
#   '29/09/2022, 2:22\u202fpm - ',
#   '29/09/2022, 2:22\u202fpm - ',
#   '29/09/2022, 2:41\u202fpm - ',
#   '29/09/2022, 2:41\u202fpm - ',
#   '29/09/2022, 2:41\u202fpm - ',
#   '29/09/2022, 2:42\u202fpm - ',
#   '29/09/2022, 2:42\u202fpm - ',
#   '29/09/2022, 2:43\u202fpm - ',
#   '29/09/2022, 2:44\u202fpm - ',
#   '29/09/2022, 2:44\u202fpm - ',
#   '29/09/2022, 2:53\u202fpm - ',
#   '29/09/2022, 2:53\u202fpm - ',
#   '29/09/2022, 2:54\u202fpm - ',
#   '29/09/2022, 2:54\u202fpm - ',
#   '29/09/2022, 2:54\u202fpm - ',
#   '29/09/2022, 2:55\u202fpm - ',
#   '29/09/2022, 2:55\u202fpm - ',
#   '29/09/2022, 2:56\u202fpm - ',
#   '29/09/2022, 2:57\u202fpm - ',
#   '29/09/2022, 2:59\u202fpm - ',
#   '29/09/2022, 2:59\u202fpm - ',
#   '29/09/2022, 3:00\u202fpm - ',
#   '29/09/2022, 3:00\u202fpm - ',
#   '29/09/2022, 3:01\u202fpm - ',
#   '29/09/2022, 3:01\u202fpm - ',
#   '29/09/2022, 3:01\u202fpm - ',
#   '29/09/2022, 3:04\u202fpm - ',
#   '29/09/2022, 3:05\u202fpm - ',
#   '29/09/2022, 3:08\u202fpm - ',
#   '29/09/2022, 3:16\u202fpm - ',
#   '29/09/2022, 3:18\u202fpm - ',
#   '29/09/2022, 3:19\u202fpm - ',
#   '29/09/2022, 3:19\u202fpm - ',
#   '29/09/2022, 3:19\u202fpm - ',
#   '29/09/2022, 3:20\u202fpm - ',
#   '29/09/2022, 3:22\u202fpm - ',
#   '29/09/2022, 3:24\u202fpm - ',
#   '29/09/2022, 3:24\u202fpm - ',
#   '29/09/2022, 3:25\u202fpm - ',
#   '29/09/2022, 3:25\u202fpm - ',
#   '29/09/2022, 3:25\u202fpm - ',
#   '29/09/2022, 3:26\u202fpm - ',
#   '29/09/2022, 3:26\u202fpm - ',
#   '29/09/2022, 3:27\u202fpm - ',
#   '29/09/2022, 3:27\u202fpm - ',
#   '29/09/2022, 3:27\u202fpm - ',
#   '29/09/2022, 3:27\u202fpm - ',
#   '29/09/2022, 3:27\u202fpm - ',
#   '29/09/2022, 3:27\u202fpm - ',
#   '29/09/2022, 3:28\u202fpm - ',
#   '29/09/2022, 3:28\u202fpm - ',
#   '29/09/2022, 3:29\u202fpm - ',
#   '29/09/2022, 3:30\u202fpm - ',
#   '29/09/2022, 3:32\u202fpm - ',
#   '29/09/2022, 3:35\u202fpm - ',
#   '29/09/2022, 5:04\u202fpm - ',
#   '29/09/2022, 5:04\u202fpm - ',
#   '29/09/2022, 5:04\u202fpm - ',
#   '29/09/2022, 5:04\u202fpm - ',
#   '29/09/2022, 5:12\u202fpm - ',
#   '29/09/2022, 6:20\u202fpm - ',
#   '29/09/2022, 6:20\u202fpm - ',
#   '29/09/2022, 7:34\u202fpm - ',
#   '30/09/2022, 6:51\u202fam - ',
#   '30/09/2022, 6:51\u202fam - ',
#   '30/09/2022, 6:53\u202fam - ',
#   '30/09/2022, 6:54\u202fam - ',
#   '30/09/2022, 6:54\u202fam - ',
#   '30/09/2022, 6:54\u202fam - ',
#   '30/09/2022, 6:55\u202fam - ',
#   '30/09/2022, 6:55\u202fam - ',
#   '30/09/2022, 6:55\u202fam - ',
#   '30/09/2022, 6:56\u202fam - ',
#   '30/09/2022, 6:57\u202fam - ',
#   '30/09/2022, 9:49\u202fpm - ',
#   '01/10/2022, 10:09\u202fam - ',
#   '04/10/2022, 7:22\u202fpm - ',
#   '04/10/2022, 7:22\u202fpm - ',
#   '04/10/2022, 8:04\u202fpm - ',
#   '04/10/2022, 8:43\u202fpm - ',
#   '04/10/2022, 8:44\u202fpm - ',
#   '04/10/2022, 8:48\u202fpm - ',
#   '04/10/2022, 8:49\u202fpm - ',
#   '04/10/2022, 8:49\u202fpm - ',
#   '04/10/2022, 8:49\u202fpm - ',
#   '04/10/2022, 8:50\u202fpm - ',
#   '04/10/2022, 8:50\u202fpm - ',
#   '04/10/2022, 8:51\u202fpm - ',
#   '04/10/2022, 8:52\u202fpm - ',
#   '04/10/2022, 8:52\u202fpm - ',
#   '04/10/2022, 8:51\u202fpm - ',
#   '04/10/2022, 8:51\u202fpm - ',
#   '04/10/2022, 8:53\u202fpm - ',
#   '04/10/2022, 8:54\u202fpm - ',
#   '04/10/2022, 8:53\u202fpm - ',
#   '04/10/2022, 8:54\u202fpm - ',
#   '04/10/2022, 8:54\u202fpm - ',
#   '04/10/2022, 8:54\u202fpm - ',
#   '04/10/2022, 8:55\u202fpm - ',
#   '04/10/2022, 8:55\u202fpm - ',
#   '04/10/2022, 8:56\u202fpm - ',
#   '04/10/2022, 8:56\u202fpm - ',
#   '04/10/2022, 8:57\u202fpm - ',
#   '04/10/2022, 8:57\u202fpm - ',
#   '04/10/2022, 8:58\u202fpm - ',
#   '04/10/2022, 9:03\u202fpm - ',
#   '04/10/2022, 9:03\u202fpm - ',
#   '04/10/2022, 9:03\u202fpm - ',
#   '04/10/2022, 9:41\u202fpm - ',
#   '04/10/2022, 9:41\u202fpm - ',
#   '05/10/2022, 7:59\u202fpm - ',
#   '05/10/2022, 8:32\u202fpm - ',
#   '05/10/2022, 8:32\u202fpm - ',
#   '05/10/2022, 8:35\u202fpm - ',
#   '05/10/2022, 8:36\u202fpm - ',
#   '05/10/2022, 8:44\u202fpm - ',
#   '05/10/2022, 9:14\u202fpm - ',
#   '06/10/2022, 5:54\u202fam - ',
#   '19/11/2022, 11:13\u202fam - ',
#   '19/11/2022, 3:39\u202fpm - ',
#   '19/11/2022, 3:42\u202fpm - ',
#   '19/11/2022, 3:43\u202fpm - ',
#   '19/11/2022, 3:46\u202fpm - ',
#   '19/11/2022, 3:47\u202fpm - ',
#   '19/11/2022, 3:47\u202fpm - ',
#   '19/11/2022, 3:50\u202fpm - ',
#   '19/11/2022, 3:51\u202fpm - ',
#   '19/11/2022, 3:53\u202fpm - ',
#   '19/11/2022, 3:53\u202fpm - ',
#   '19/11/2022, 3:54\u202fpm - ',
#   '19/11/2022, 3:55\u202fpm - ',
#   '19/11/2022, 3:57\u202fpm - ',
#   '22/11/2022, 6:48\u202fpm - ',
#   '22/11/2022, 8:08\u202fpm - ',
#   '22/11/2022, 8:28\u202fpm - ',
#   '22/11/2022, 8:45\u202fpm - ',
#   '22/11/2022, 8:59\u202fpm - ',
#   '22/11/2022, 9:06\u202fpm - ',
#   '22/11/2022, 9:19\u202fpm - ',
#   '22/11/2022, 9:20\u202fpm - ',
#   '22/11/2022, 9:21\u202fpm - ',
#   '22/11/2022, 9:24\u202fpm - ',
#   '22/11/2022, 9:25\u202fpm - ',
#   '22/11/2022, 9:25\u202fpm - ',
#   '22/11/2022, 9:25\u202fpm - ',
#   '22/11/2022, 9:26\u202fpm - ',
#   '22/11/2022, 9:26\u202fpm - ',
#   '22/11/2022, 9:27\u202fpm - ',
#   '22/11/2022, 9:27\u202fpm - ',
#   '22/11/2022, 9:27\u202fpm - ',
#   '22/11/2022, 9:28\u202fpm - ',
#   '22/11/2022, 9:29\u202fpm - ',
#   '22/11/2022, 9:30\u202fpm - ',
#   '22/11/2022, 9:30\u202fpm - ',
#   '22/11/2022, 9:31\u202fpm - ',
#   '22/11/2022, 9:32\u202fpm - ',
#   '22/11/2022, 9:32\u202fpm - ',
#   '22/11/2022, 9:33\u202fpm - ',
#   '22/11/2022, 9:33\u202fpm - ',
#   '22/11/2022, 9:33\u202fpm - ',
#   '22/11/2022, 9:34\u202fpm - ',
#   '22/11/2022, 9:35\u202fpm - ',
#   '22/11/2022, 9:39\u202fpm - ',
#   '29/11/2022, 9:45\u202fam - ',
#   '29/11/2022, 10:45\u202fam - ',
#   '06/12/2022, 8:33\u202fpm - ',
#   '10/12/2022, 5:16\u202fpm - ',
#   '10/12/2022, 6:19\u202fpm - ',
#   '02/01/2023, 10:04\u202fam - ',
#   '02/01/2023, 11:54\u202fam - ',
#   '02/01/2023, 8:09\u202fpm - ',
#   '02/01/2023, 8:15\u202fpm - ',
#   '04/01/2023, 11:14\u202fam - ',
#   '08/01/2023, 7:38\u202fpm - ',
#   '26/01/2023, 8:11\u202fpm - ',
#   '01/02/2023, 7:33\u202fpm - ',
#   '01/02/2023, 7:33\u202fpm - ',
#   '01/02/2023, 7:34\u202fpm - ',
#   '01/02/2023, 7:34\u202fpm - ',
#   '01/02/2023, 7:34\u202fpm - ',
#   '01/02/2023, 7:35\u202fpm - ',
#   '01/02/2023, 7:35\u202fpm - ',
#   '01/02/2023, 7:35\u202fpm - ',
#   '01/02/2023, 7:36\u202fpm - ',
#   '01/02/2023, 7:36\u202fpm - ',
#   '01/02/2023, 7:36\u202fpm - ',
#   '01/02/2023, 7:36\u202fpm - ',
#   '01/02/2023, 7:36\u202fpm - ',
#   '01/02/2023, 7:37\u202fpm - ',
#   '01/02/2023, 7:37\u202fpm - ',
#   '01/02/2023, 7:37\u202fpm - ',
#   '01/02/2023, 7:38\u202fpm - ',
#   '01/02/2023, 8:02\u202fpm - ',
#   '01/02/2023, 8:04\u202fpm - ',
#   '01/02/2023, 8:04\u202fpm - ',
#   '01/02/2023, 8:05\u202fpm - ',
#   '01/02/2023, 8:05\u202fpm - ',
#   '01/02/2023, 8:05\u202fpm - ',
#   '01/02/2023, 8:06\u202fpm - ',
#   '01/02/2023, 8:06\u202fpm - ',
#   '01/02/2023, 8:07\u202fpm - ',
#   '01/02/2023, 8:07\u202fpm - ',
#   '01/02/2023, 8:07\u202fpm - ',
#   '01/02/2023, 8:07\u202fpm - ',
#   '01/02/2023, 8:37\u202fpm - ',
#   '02/02/2023, 8:16\u202fpm - ',
#   '02/02/2023, 8:21\u202fpm - ',
#   '02/02/2023, 8:54\u202fpm - ',
#   '02/02/2023, 8:55\u202fpm - ',
#   '02/02/2023, 8:56\u202fpm - ',
#   '02/02/2023, 8:56\u202fpm - ',
#   '02/02/2023, 8:56\u202fpm - ',
#   '02/02/2023, 8:57\u202fpm - ',
#   '02/02/2023, 8:58\u202fpm - ',
#   '02/02/2023, 8:58\u202fpm - ',
#   '02/02/2023, 8:59\u202fpm - ',
#   '02/02/2023, 8:59\u202fpm - ',
#   '02/02/2023, 8:59\u202fpm - ',
#   '02/02/2023, 8:59\u202fpm - ',
#   '02/02/2023, 9:00\u202fpm - ',
#   '02/02/2023, 9:01\u202fpm - ',
#   '02/02/2023, 10:13\u202fpm - ',
#   '02/02/2023, 10:24\u202fpm - ',
#   '02/02/2023, 10:25\u202fpm - ',
#   '02/02/2023, 10:26\u202fpm - ',
#   '02/02/2023, 10:28\u202fpm - ',
#   '02/02/2023, 10:32\u202fpm - ',
#   '02/02/2023, 10:33\u202fpm - ',
#   '02/02/2023, 10:34\u202fpm - ',
#   '04/02/2023, 6:24\u202fpm - ',
#   '04/02/2023, 8:13\u202fpm - ',
#   '04/02/2023, 8:13\u202fpm - ',
#   '04/02/2023, 8:14\u202fpm - ',
#   '04/02/2023, 8:14\u202fpm - ',
#   '04/02/2023, 8:14\u202fpm - ',
#   '04/02/2023, 8:15\u202fpm - ',
#   '04/02/2023, 8:22\u202fpm - ',
#   '04/02/2023, 8:22\u202fpm - ',
#   '04/02/2023, 8:23\u202fpm - ',
#   '04/02/2023, 8:23\u202fpm - ',
#   '04/02/2023, 8:23\u202fpm - ',
#   '04/02/2023, 8:24\u202fpm - ',
#   '04/02/2023, 8:24\u202fpm - ',
#   '04/02/2023, 8:25\u202fpm - ',
# ...
#   '16/03/2023, 9:54\u202fam - ',
#   '17/03/2023, 8:10\u202fam - ',
#   '17/03/2023, 8:11\u202fam - ',
#   '17/03/2023, 7:37\u202fpm - ',
#   '17/03/2023, 7:38\u202fpm - ',
#   '17/03/2023, 7:38\u202fpm - ',
#   '17/03/2023, 7:38\u202fpm - ',
#   '17/03/2023, 7:38\u202fpm - ',
#   '17/03/2023, 7:38\u202fpm - ',
#   '17/03/2023, 7:38\u202fpm - ',
#   '17/03/2023, 7:39\u202fpm - ',
#   '17/03/2023, 7:39\u202fpm - ',
#   '17/03/2023, 7:40\u202fpm - ',
#   '17/03/2023, 7:41\u202fpm - ',
#   '17/03/2023, 7:42\u202fpm - ',
#   '17/03/2023, 8:04\u202fpm - ',
#   '17/03/2023, 8:09\u202fpm - ',
#   '17/03/2023, 8:10\u202fpm - ',
#   '17/03/2023, 8:10\u202fpm - ',
#   '17/03/2023, 8:10\u202fpm - ',
#   '17/03/2023, 8:11\u202fpm - ',
#   '17/03/2023, 8:11\u202fpm - ',
#   '17/03/2023, 8:11\u202fpm - ',
#   '17/03/2023, 8:11\u202fpm - ',
#   '17/03/2023, 8:11\u202fpm - ',
#   '17/03/2023, 8:12\u202fpm - ',
#   '17/03/2023, 8:12\u202fpm - ',
#   '17/03/2023, 8:12\u202fpm - ',
#   '17/03/2023, 8:12\u202fpm - ',
#   '17/03/2023, 8:12\u202fpm - ',
#   '17/03/2023, 8:13\u202fpm - ',
#   '17/03/2023, 8:13\u202fpm - ',
#   '17/03/2023, 8:14\u202fpm - ',
#   '17/03/2023, 8:14\u202fpm - ',
#   '17/03/2023, 8:14\u202fpm - ',
#   '17/03/2023, 8:15\u202fpm - ',
#   '17/03/2023, 8:15\u202fpm - ',
#   '17/03/2023, 8:15\u202fpm - ',
#   '17/03/2023, 8:15\u202fpm - ',
#   '17/03/2023, 8:16\u202fpm - ',
#   '17/03/2023, 8:16\u202fpm - ',
#   '17/03/2023, 8:16\u202fpm - ',
#   '17/03/2023, 8:16\u202fpm - ',
#   '17/03/2023, 8:17\u202fpm - ',
#   '17/03/2023, 8:17\u202fpm - ',
#   '17/03/2023, 8:17\u202fpm - ',
#   '17/03/2023, 8:18\u202fpm - ',
#   '17/03/2023, 8:18\u202fpm - ',
#   '17/03/2023, 9:19\u202fpm - ',
#   '17/03/2023, 9:39\u202fpm - ',
#   '17/03/2023, 9:39\u202fpm - ',
#   '17/03/2023, 9:40\u202fpm - ',
#   '17/03/2023, 9:40\u202fpm - ',
#   '17/03/2023, 9:40\u202fpm - ',
#   '17/03/2023, 9:40\u202fpm - ',
#   '17/03/2023, 9:40\u202fpm - ',
#   '17/03/2023, 9:40\u202fpm - ',
#   '17/03/2023, 9:40\u202fpm - ',
#   '17/03/2023, 9:40\u202fpm - ',
#   '17/03/2023, 9:40\u202fpm - ',
#   '17/03/2023, 9:41\u202fpm - ',
#   '17/03/2023, 9:41\u202fpm - ',
#   '17/03/2023, 9:41\u202fpm - ',
#   '17/03/2023, 9:41\u202fpm - ',
#   '17/03/2023, 9:41\u202fpm - ',
#   '17/03/2023, 9:41\u202fpm - ',
#   '17/03/2023, 9:42\u202fpm - ',
#   '17/03/2023, 9:42\u202fpm - ',
#   '17/03/2023, 9:42\u202fpm - ',
#   '17/03/2023, 9:42\u202fpm - ',
#   '17/03/2023, 9:42\u202fpm - ',
#   '17/03/2023, 9:43\u202fpm - ',
#   '17/03/2023, 9:43\u202fpm - ',
#   '17/03/2023, 9:43\u202fpm - ',
#   '17/03/2023, 9:43\u202fpm - ',
#   '17/03/2023, 9:43\u202fpm - ',
#   '17/03/2023, 9:43\u202fpm - ',
#   '17/03/2023, 9:44\u202fpm - ',
#   '17/03/2023, 9:44\u202fpm - ',
#   '17/03/2023, 9:44\u202fpm - ',
#   '17/03/2023, 9:44\u202fpm - ',
#   '17/03/2023, 9:45\u202fpm - ',
#   '17/03/2023, 9:45\u202fpm - ',
#   '17/03/2023, 9:45\u202fpm - ',
#   '17/03/2023, 9:45\u202fpm - ',
#   '17/03/2023, 9:46\u202fpm - ',
#   '17/03/2023, 9:46\u202fpm - ',
#   '17/03/2023, 9:49\u202fpm - ',
#   '25/03/2023, 7:39\u202fpm - ',
#   '25/03/2023, 7:42\u202fpm - ',
#   '25/03/2023, 8:02\u202fpm - ',
#   '25/03/2023, 8:07\u202fpm - ',
#   '25/03/2023, 8:08\u202fpm - ',
#   '25/03/2023, 8:08\u202fpm - ',
#   '25/03/2023, 8:08\u202fpm - ',
#   '24/04/2023, 2:16\u202fpm - ',
#   '24/04/2023, 5:53\u202fpm - ',
#   '25/04/2023, 7:28\u202fpm - ',
#   '25/04/2023, 7:38\u202fpm - ',
#   '25/04/2023, 8:11\u202fpm - ',
#   '25/04/2023, 8:18\u202fpm - ',
#   '25/04/2023, 9:07\u202fpm - ',
#   '25/04/2023, 9:07\u202fpm - ',
#   '25/04/2023, 10:14\u202fpm - ',
#   '25/04/2023, 10:14\u202fpm - ',
#   '25/04/2023, 10:31\u202fpm - ',
#   '25/04/2023, 10:31\u202fpm - ',
#   '25/04/2023, 10:32\u202fpm - ',
#   '25/04/2023, 10:32\u202fpm - ',
#   '25/04/2023, 10:33\u202fpm - ',
#   '25/04/2023, 10:34\u202fpm - ',
#   '25/04/2023, 10:34\u202fpm - ',
#   '25/04/2023, 10:54\u202fpm - ',
#   '26/04/2023, 9:10\u202fpm - ',
#   '26/04/2023, 11:24\u202fpm - ',
#   '26/04/2023, 11:25\u202fpm - ',
#   '27/04/2023, 8:37\u202fam - ',
#   '27/04/2023, 1:58\u202fpm - ',
#   '27/04/2023, 1:58\u202fpm - ',
#   '27/04/2023, 1:59\u202fpm - ',
#   '27/04/2023, 1:59\u202fpm - ',
#   '27/04/2023, 1:59\u202fpm - ',
#   '27/04/2023, 2:00\u202fpm - ',
#   '27/04/2023, 2:00\u202fpm - ',
#   '27/04/2023, 2:00\u202fpm - ',
#   '27/04/2023, 2:00\u202fpm - ',
#   '27/04/2023, 2:00\u202fpm - ',
#   '27/04/2023, 2:01\u202fpm - ',
#   '27/04/2023, 2:01\u202fpm - ',
#   '27/04/2023, 2:01\u202fpm - ',
#   '27/04/2023, 2:02\u202fpm - ',
#   '27/04/2023, 2:03\u202fpm - ',
#   '27/04/2023, 2:03\u202fpm - ',
#   '27/04/2023, 2:04\u202fpm - ',
#   '27/04/2023, 2:04\u202fpm - ',
#   '27/04/2023, 2:04\u202fpm - ',
#   '27/04/2023, 2:04\u202fpm - ',
#   '27/04/2023, 2:05\u202fpm - ',
#   '28/04/2023, 6:29\u202fam - ',
#   '28/04/2023, 6:42\u202fam - ',
#   '05/05/2023, 6:04\u202fpm - ',
#   '05/05/2023, 6:04\u202fpm - ',
#   '05/05/2023, 6:07\u202fpm - ',
#   '09/05/2023, 5:42\u202fpm - ',
#   '09/05/2023, 5:42\u202fpm - ',
#   '11/05/2023, 9:00\u202fpm - ',
#   '12/05/2023, 11:54\u202fam - ',
#   '12/05/2023, 11:54\u202fam - ',
#   '12/05/2023, 11:57\u202fam - ',
#   '12/05/2023, 11:57\u202fam - ',
#   '12/05/2023, 9:26\u202fpm - ',
#   '12/05/2023, 9:27\u202fpm - ',
#   '12/05/2023, 9:47\u202fpm - ',
#   '12/05/2023, 9:48\u202fpm - ',
#   '12/05/2023, 10:17\u202fpm - ',
#   '12/05/2023, 10:41\u202fpm - ',
#   '12/05/2023, 10:42\u202fpm - ',
#   '12/05/2023, 10:43\u202fpm - ',
#   '15/05/2023, 7:29\u202fpm - ',
#   '15/05/2023, 7:30\u202fpm - ',
#   '15/05/2023, 9:53\u202fpm - ',
#   '15/05/2023, 9:54\u202fpm - ',
#   '17/05/2023, 2:11\u202fpm - ',
#   '19/05/2023, 9:40\u202fpm - ',
#   '19/05/2023, 9:40\u202fpm - ',
#   '19/05/2023, 10:14\u202fpm - ',
#   '19/05/2023, 10:21\u202fpm - ',
#   '19/05/2023, 10:23\u202fpm - ',
#   '19/05/2023, 10:23\u202fpm - ',
#   '19/05/2023, 10:23\u202fpm - ',
#   '19/05/2023, 10:26\u202fpm - ',
#   '19/05/2023, 10:27\u202fpm - ',
#   '20/05/2023, 7:18\u202fam - ',
#   '20/05/2023, 8:21\u202fam - ',
#   '20/05/2023, 8:22\u202fam - ',
#   '20/05/2023, 8:22\u202fam - ',
#   '20/05/2023, 9:58\u202fam - ',
#   '20/05/2023, 10:12\u202fam - ',
#   '20/05/2023, 10:16\u202fam - ',
#   '20/05/2023, 10:16\u202fam - ',
#   '20/05/2023, 10:16\u202fam - ',
#   '20/05/2023, 12:50\u202fpm - ',
#   '20/05/2023, 6:05\u202fpm - ',
#   '20/05/2023, 7:02\u202fpm - ',
#   '20/05/2023, 7:03\u202fpm - ',
#   '20/05/2023, 9:24\u202fpm - ',
#   '23/05/2023, 10:40\u202fam - ',
#   '23/05/2023, 5:49\u202fpm - ',
#   '23/05/2023, 8:21\u202fpm - ',
#   '23/05/2023, 8:21\u202fpm - ',
#   '23/05/2023, 8:23\u202fpm - ',
#   '23/05/2023, 8:26\u202fpm - ',
#   '24/05/2023, 2:23\u202fpm - ',
#   '24/05/2023, 2:23\u202fpm - ',
#   '24/05/2023, 3:51\u202fpm - ',
#   '24/05/2023, 3:52\u202fpm - ',
#   '24/05/2023, 3:53\u202fpm - ',
#   '24/05/2023, 3:53\u202fpm - ',
#   '24/05/2023, 3:53\u202fpm - ',
#   '24/05/2023, 3:59\u202fpm - ',
#   '24/05/2023, 4:00\u202fpm - ',
#   '24/05/2023, 4:01\u202fpm - ',
#   '24/05/2023, 4:01\u202fpm - ',
#   '24/05/2023, 4:01\u202fpm - ',
#   '24/05/2023, 4:02\u202fpm - ',
#   '24/05/2023, 4:02\u202fpm - ',
#   '24/05/2023, 4:02\u202fpm - ',
#   '24/05/2023, 4:03\u202fpm - ',
#   '24/05/2023, 10:01\u202fpm - ',
#   '24/05/2023, 10:02\u202fpm - ',
#   '27/05/2023, 6:19\u202fam - ',
#   '27/05/2023, 6:19\u202fam - ',
#   '27/05/2023, 9:39\u202fam - ',
#   '27/05/2023, 1:02\u202fpm - ',
#   '29/05/2023, 5:01\u202fpm - ',
#   '29/05/2023, 5:54\u202fpm - ',
#   '29/05/2023, 10:15\u202fpm - ',
#   '30/05/2023, 11:18\u202fam - ',
#   '30/05/2023, 11:30\u202fam - ',
#   '30/05/2023, 11:31\u202fam - ',
#   '30/05/2023, 11:31\u202fam - ',
#   '30/05/2023, 11:32\u202fam - ',
#   '30/05/2023, 11:32\u202fam - ',
#   '30/05/2023, 11:33\u202fam - ',
#   '30/05/2023, 11:33\u202fam - ',
#   '30/05/2023, 11:33\u202fam - ',
#   '30/05/2023, 11:34\u202fam - ',
#   '30/05/2023, 11:34\u202fam - ',
#   '30/05/2023, 11:34\u202fam - ',
#   '30/05/2023, 11:34\u202fam - ',
#   '30/05/2023, 11:34\u202fam - ',
#   '30/05/2023, 11:35\u202fam - ',
#   '30/05/2023, 11:35\u202fam - ',
#   '30/05/2023, 11:35\u202fam - ',
#   '30/05/2023, 11:36\u202fam - ',
#   '30/05/2023, 11:36\u202fam - ',
#   '30/05/2023, 11:37\u202fam - ',
#   '30/05/2023, 11:40\u202fam - ',
#   '30/05/2023, 11:41\u202fam - ',
#   '30/05/2023, 11:41\u202fam - ',
#   '30/05/2023, 11:41\u202fam - ',
#   '30/05/2023, 11:43\u202fam - ',
#   '30/05/2023, 11:44\u202fam - ',
#   '30/05/2023, 11:44\u202fam - ',
#   '30/05/2023, 11:44\u202fam - ',
#   '30/05/2023, 11:44\u202fam - ',
#   '30/05/2023, 11:46\u202fam - ',
#   '30/05/2023, 11:47\u202fam - ',
#   '30/05/2023, 11:47\u202fam - ',
#   '30/05/2023, 11:47\u202fam - ',
#   '30/05/2023, 11:48\u202fam - ',
#   '30/05/2023, 11:48\u202fam - ',
#   '30/05/2023, 11:48\u202fam - ',
#   '30/05/2023, 11:50\u202fam - ',
#   '30/05/2023, 11:50\u202fam - ',
#   '30/05/2023, 11:50\u202fam - ',
#   '30/05/2023, 11:52\u202fam - ',
#   '30/05/2023, 11:53\u202fam - ',
#   '30/05/2023, 11:54\u202fam - ',
#   '30/05/2023, 11:58\u202fam - ',
#   '30/05/2023, 11:58\u202fam - ',
#   '30/05/2023, 11:58\u202fam - ',
#   '30/05/2023, 11:59\u202fam - ',
#   '30/05/2023, 11:59\u202fam - ',
#   '30/05/2023, 12:00\u202fpm - ',
#   '30/05/2023, 12:02\u202fpm - ',
#   '30/05/2023, 12:02\u202fpm - ',
#   '30/05/2023, 12:03\u202fpm - ',
#   '30/05/2023, 12:03\u202fpm - ',
#   '30/05/2023, 12:05\u202fpm - ',
#   '30/05/2023, 12:05\u202fpm - ',
#   '30/05/2023, 12:06\u202fpm - ',
#   '30/05/2023, 12:06\u202fpm - ',
#   '30/05/2023, 12:06\u202fpm - ',
#   '30/05/2023, 12:07\u202fpm - ',
#   '30/05/2023, 12:07\u202fpm - ',
#   '30/05/2023, 12:07\u202fpm - ',
#   '30/05/2023, 12:08\u202fpm - ',
#   '30/05/2023, 12:08\u202fpm - ',
#   '30/05/2023, 12:08\u202fpm - ',
#   '30/05/2023, 12:08\u202fpm - ',
#   '30/05/2023, 12:09\u202fpm - ',
#   '30/05/2023, 12:09\u202fpm - ',
#   '30/05/2023, 12:09\u202fpm - ',
#   '30/05/2023, 12:10\u202fpm - ',
#   '30/05/2023, 12:11\u202fpm - ',
#   '30/05/2023, 12:11\u202fpm - ',
#   '30/05/2023, 12:11\u202fpm - ',
#   '30/05/2023, 12:11\u202fpm - ',
#   '30/05/2023, 12:11\u202fpm - ',
#   '30/05/2023, 12:12\u202fpm - ',
#   '30/05/2023, 12:12\u202fpm - ',
#   '30/05/2023, 12:12\u202fpm - ',
#   '30/05/2023, 12:12\u202fpm - ',
#   '30/05/2023, 12:12\u202fpm - ',
#   '30/05/2023, 12:13\u202fpm - ',
#   '30/05/2023, 12:14\u202fpm - ',
#   '30/05/2023, 12:15\u202fpm - ',
#   '30/05/2023, 12:15\u202fpm - ',
#   '30/05/2023, 12:16\u202fpm - ',
#   '30/05/2023, 12:52\u202fpm - ',
#   '30/05/2023, 12:52\u202fpm - ',
#   '31/05/2023, 11:19\u202fam - ',
#   '31/05/2023, 9:32\u202fpm - ',
#   '04/06/2023, 9:58\u202fpm - ',
#   '04/06/2023, 10:22\u202fpm - ',
#   '05/06/2023, 7:40\u202fpm - ',
#   '05/06/2023, 8:12\u202fpm - ',
#   '05/06/2023, 8:13\u202fpm - ',
#   '05/06/2023, 9:12\u202fpm - ',
#   '05/06/2023, 9:21\u202fpm - ',
#   '05/06/2023, 9:22\u202fpm - ',
#   '05/06/2023, 9:22\u202fpm - ',
#   '05/06/2023, 9:24\u202fpm - ',
#   '05/06/2023, 9:25\u202fpm - ',
#   '05/06/2023, 9:25\u202fpm - ',
#   '05/06/2023, 9:28\u202fpm - ',
#   '05/06/2023, 9:30\u202fpm - ',
#   '05/06/2023, 9:32\u202fpm - ',
#   '05/06/2023, 9:34\u202fpm - ',
#   '05/06/2023, 9:35\u202fpm - ',
#   '05/06/2023, 9:40\u202fpm - ',
#   '05/06/2023, 9:40\u202fpm - ',
#   '05/06/2023, 9:41\u202fpm - ',
#   '05/06/2023, 9:46\u202fpm - ',
#   '05/06/2023, 9:52\u202fpm - ',
#   '05/06/2023, 10:06\u202fpm - ',
#   '05/06/2023, 10:17\u202fpm - ',
#   '22/06/2023, 9:34\u202fpm - ',
#   '22/06/2023, 9:51\u202fpm - ',
#   '22/06/2023, 9:52\u202fpm - ',
#   '23/06/2023, 5:41\u202fam - ',
#   '23/06/2023, 6:33\u202fpm - ',
#   '23/06/2023, 6:45\u202fpm - ',
#   '23/06/2023, 6:56\u202fpm - ',
#   '11/07/2023, 11:09\u202fpm - ',
#   '12/07/2023, 3:08\u202fpm - ',
#   '13/07/2023, 7:40\u202fam - ',
#   '13/07/2023, 11:50\u202fam - ',
#   '13/07/2023, 11:27\u202fpm - ',
#   '13/07/2023, 11:27\u202fpm - ',
#   '13/07/2023, 11:34\u202fpm - ',
#   '13/07/2023, 11:44\u202fpm - ',
#   '14/07/2023, 4:23\u202fam - ',
#   '14/07/2023, 7:25\u202fam - ',
#   '14/07/2023, 9:48\u202fam - ',
#   '14/07/2023, 10:16\u202fam - ',
#   '14/07/2023, 10:17\u202fam - ',
#   '14/07/2023, 10:17\u202fam - ',
#   '14/07/2023, 10:17\u202fam - ',
#   '14/07/2023, 10:18\u202fam - ',
#   '14/07/2023, 10:18\u202fam - ',
#   '14/07/2023, 10:18\u202fam - ',
#   '14/07/2023, 10:18\u202fam - ',
#   '14/07/2023, 10:18\u202fam - ',
#   '14/07/2023, 10:18\u202fam - ',
#   '14/07/2023, 10:20\u202fam - ',
#   '14/07/2023, 10:20\u202fam - ',
#   '14/07/2023, 10:24\u202fam - ',
#   '14/07/2023, 10:29\u202fam - ',
#   '14/07/2023, 10:45\u202fam - ',
#   '14/07/2023, 10:45\u202fam - ',
#   '14/07/2023, 11:04\u202fam - ',
#   '14/07/2023, 11:26\u202fam - ',
#   '14/07/2023, 11:27\u202fam - ',
#   '14/07/2023, 11:30\u202fam - ',
#   '14/07/2023, 11:30\u202fam - ',
#   '14/07/2023, 11:31\u202fam - ',
#   '14/07/2023, 11:31\u202fam - ',
#   '14/07/2023, 11:32\u202fam - ',
#   '14/07/2023, 11:33\u202fam - ',
#   '14/07/2023, 11:33\u202fam - ',
#   '14/07/2023, 11:33\u202fam - ',
#   '14/07/2023, 4:08\u202fpm - ',
#   '14/07/2023, 5:30\u202fpm - ',
#   '14/07/2023, 5:30\u202fpm - ',
#   '14/07/2023, 5:30\u202fpm - ',
#   '14/07/2023, 8:00\u202fpm - ',
#   '14/07/2023, 10:46\u202fpm - ',
#   '15/07/2023, 11:09\u202fpm - ',
#   '15/07/2023, 11:09\u202fpm - ',
#   '15/07/2023, 11:09\u202fpm - ',
#   '15/07/2023, 11:10\u202fpm - ',
#   '15/07/2023, 11:10\u202fpm - ',
#   '15/07/2023, 11:10\u202fpm - ',
#   '15/07/2023, 11:10\u202fpm - ',
#   '15/07/2023, 11:12\u202fpm - ',
#   '15/07/2023, 11:12\u202fpm - ',
#   '15/07/2023, 11:12\u202fpm - ',
#   '15/07/2023, 11:12\u202fpm - ',
#   '15/07/2023, 11:13\u202fpm - ',
#   '15/07/2023, 11:13\u202fpm - ',
#   '15/07/2023, 11:14\u202fpm - ',
#   '15/07/2023, 11:14\u202fpm - ',
#   '15/07/2023, 11:14\u202fpm - ',
#   '15/07/2023, 11:15\u202fpm - ',
#   '15/07/2023, 11:17\u202fpm - ',
#   '15/07/2023, 11:19\u202fpm - ',
#   '15/07/2023, 11:20\u202fpm - ',
#   '15/07/2023, 11:21\u202fpm - ',
#   '15/07/2023, 11:21\u202fpm - ',
#   '15/07/2023, 11:22\u202fpm - ',
#   '15/07/2023, 11:22\u202fpm - ',
#   '15/07/2023, 11:23\u202fpm - ',
#   '15/07/2023, 11:23\u202fpm - ',
#   '15/07/2023, 11:23\u202fpm - ',
#   '15/07/2023, 11:23\u202fpm - ',
#   '15/07/2023, 11:24\u202fpm - ',
#   '15/07/2023, 11:24\u202fpm - ',
#   '15/07/2023, 11:25\u202fpm - ',
#   '15/07/2023, 11:25\u202fpm - ',
#   '15/07/2023, 11:25\u202fpm - ',
#   '15/07/2023, 11:25\u202fpm - ',
#   '15/07/2023, 11:26\u202fpm - ',
#   '15/07/2023, 11:26\u202fpm - ',
#   '15/07/2023, 11:26\u202fpm - ',
#   '15/07/2023, 11:26\u202fpm - ',
#   '15/07/2023, 11:27\u202fpm - ',
#   '15/07/2023, 11:28\u202fpm - ',
#   '15/07/2023, 11:29\u202fpm - ',
#   '15/07/2023, 11:29\u202fpm - ',
#   '15/07/2023, 11:30\u202fpm - ',
#   '15/07/2023, 11:30\u202fpm - ',
#   '15/07/2023, 11:30\u202fpm - ',
#   '15/07/2023, 11:32\u202fpm - ',
#   '15/07/2023, 11:32\u202fpm - ',
#   '15/07/2023, 11:32\u202fpm - ',
#   '15/07/2023, 11:33\u202fpm - ',
#   '15/07/2023, 11:33\u202fpm - ',
#   '15/07/2023, 11:33\u202fpm - ',
#   '15/07/2023, 11:34\u202fpm - ',
#   '15/07/2023, 11:34\u202fpm - ',
#   '15/07/2023, 11:36\u202fpm - ',
#   '15/07/2023, 11:37\u202fpm - ',
#   '15/07/2023, 11:37\u202fpm - ',
#   '15/07/2023, 11:37\u202fpm - ',
#   '15/07/2023, 11:38\u202fpm - ',
#   '15/07/2023, 11:39\u202fpm - ',
#   '15/07/2023, 11:42\u202fpm - ',
#   '15/07/2023, 11:42\u202fpm - ',
#   '15/07/2023, 11:43\u202fpm - ',
#   '15/07/2023, 11:43\u202fpm - ',
#   '16/07/2023, 8:50\u202fam - ',
#   '16/07/2023, 9:47\u202fam - ',
#   '17/07/2023, 8:44\u202fpm - ',
#   '17/07/2023, 8:44\u202fpm - ',
#   '17/07/2023, 9:40\u202fpm - ',
#   '17/07/2023, 10:30\u202fpm - ',
#   '17/07/2023, 10:33\u202fpm - ',
#   '18/07/2023, 3:40\u202fpm - ',
#   '21/07/2023, 9:28\u202fpm - ',
#   '28/07/2023, 8:45\u202fpm - ',
#   '28/07/2023, 9:14\u202fpm - ',
#   '28/07/2023, 9:14\u202fpm - ',
#   '28/07/2023, 9:39\u202fpm - ',
#   '28/07/2023, 9:40\u202fpm - ',
#   '01/08/2023, 8:35\u202fpm - ',
#   '01/08/2023, 8:36\u202fpm - ',
#   '05/08/2023, 8:07\u202fpm - ',
#   '05/08/2023, 8:26\u202fpm - ',
#   '05/08/2023, 8:40\u202fpm - ',
#   '05/08/2023, 8:42\u202fpm - ',
#   '05/08/2023, 8:42\u202fpm - ',
#   '05/08/2023, 8:43\u202fpm - ',
#   '05/08/2023, 9:04\u202fpm - ',
#   '05/08/2023, 9:45\u202fpm - ',
#   '07/08/2023, 4:52\u202fpm - ',
#   '07/08/2023, 6:33\u202fpm - ',
#   '07/08/2023, 6:33\u202fpm - ',
#   '07/08/2023, 6:50\u202fpm - ',
#   '07/08/2023, 6:50\u202fpm - ',
#   '07/08/2023, 6:50\u202fpm - ',
#   '07/08/2023, 7:24\u202fpm - ',
#   '07/08/2023, 8:06\u202fpm - ',
#   '07/08/2023, 8:09\u202fpm - ',
#   '07/08/2023, 8:19\u202fpm - ',
#   '07/08/2023, 8:22\u202fpm - ',
#   ...]}

# %%
# Check the lengths of arrays
for key, value in message_dict.items():
    print(f'Length of {key}: {len(value)}')
# Out:
# Length of user_message: 2012
# Length of message_date: 2012

# %%
df = pd.DataFrame(message_dict)

# %%
df
# Out:
#                                            user_message  \
# 0     Messages and calls are end-to-end encrypted. N...
# 1                                       Guddu...: Hlo\n
# 2                                      Khushilal: Hjr\n
# 3                                   Khushilal: Vannue\n
# 4                                        Khushilal: S\n
# ...                                                 ...
# 2007                            Khushilal: party chai\n
# 2008                                 Guddu...: Online\n
# 2009                              Guddu...: Dhanyavad\n
# 2010                             Khushilal: deu na ta\n
# 2011                                    Khushilal: ..\n
#
#                 message_date
# 0     28/09/2022, 9:21 pm -
# 1     28/09/2022, 8:23 pm -
# 2     28/09/2022, 9:43 pm -
# 3     28/09/2022, 9:43 pm -
# 4     28/09/2022, 9:43 pm -
# ...                      ...
# 2007  21/11/2023, 6:24 pm -
# 2008  21/11/2023, 6:26 pm -
# 2009  21/11/2023, 6:26 pm -
# 2010  21/11/2023, 6:43 pm -
# 2011  21/11/2023, 8:04 pm -
#
# [2012 rows x 2 columns]

# %%
# Attempt to convert the 'message_date' column to datetime
try:
    df['Date'] = pd.to_datetime(df['message_date'], format='%d/%m/%Y, %I:%M %p - ')
except ValueError as e:
    print(f"Error: {e}")

# %%
df
# Out:
#                                            user_message  \
# 0     Messages and calls are end-to-end encrypted. N...
# 1                                       Guddu...: Hlo\n
# 2                                      Khushilal: Hjr\n
# 3                                   Khushilal: Vannue\n
# 4                                        Khushilal: S\n
# ...                                                 ...
# 2007                            Khushilal: party chai\n
# 2008                                 Guddu...: Online\n
# 2009                              Guddu...: Dhanyavad\n
# 2010                             Khushilal: deu na ta\n
# 2011                                    Khushilal: ..\n
#
#                 message_date                Date
# 0     28/09/2022, 9:21 pm -  2022-09-28 21:21:00
# 1     28/09/2022, 8:23 pm -  2022-09-28 20:23:00
# 2     28/09/2022, 9:43 pm -  2022-09-28 21:43:00
# 3     28/09/2022, 9:43 pm -  2022-09-28 21:43:00
# 4     28/09/2022, 9:43 pm -  2022-09-28 21:43:00
# ...                      ...                 ...
# 2007  21/11/2023, 6:24 pm -  2023-11-21 18:24:00
# 2008  21/11/2023, 6:26 pm -  2023-11-21 18:26:00
# 2009  21/11/2023, 6:26 pm -  2023-11-21 18:26:00
# 2010  21/11/2023, 6:43 pm -  2023-11-21 18:43:00
# 2011  21/11/2023, 8:04 pm -  2023-11-21 20:04:00
#
# [2012 rows x 3 columns]

# %%
df=df.drop(columns=['message_date'])

# %%
df
# Out:
#                                            user_message                Date
# 0     Messages and calls are end-to-end encrypted. N... 2022-09-28 21:21:00
# 1                                       Guddu...: Hlo\n 2022-09-28 20:23:00
# 2                                      Khushilal: Hjr\n 2022-09-28 21:43:00
# 3                                   Khushilal: Vannue\n 2022-09-28 21:43:00
# 4                                        Khushilal: S\n 2022-09-28 21:43:00
# ...                                                 ...                 ...
# 2007                            Khushilal: party chai\n 2023-11-21 18:24:00
# 2008                                 Guddu...: Online\n 2023-11-21 18:26:00
# 2009                              Guddu...: Dhanyavad\n 2023-11-21 18:26:00
# 2010                             Khushilal: deu na ta\n 2023-11-21 18:43:00
# 2011                                    Khushilal: ..\n 2023-11-21 20:04:00
#
# [2012 rows x 2 columns]

# %%
df.shape
# Out:
# (2012, 2)

# %%
df['user_message']
# Out:
# 0       Messages and calls are end-to-end encrypted. N...
# 1                                         Guddu...: Hlo\n
# 2                                        Khushilal: Hjr\n
# 3                                     Khushilal: Vannue\n
# 4                                          Khushilal: S\n
#                               ...
# 2007                              Khushilal: party chai\n
# 2008                                   Guddu...: Online\n
# 2009                                Guddu...: Dhanyavad\n
# 2010                               Khushilal: deu na ta\n
# 2011                                      Khushilal: ..\n
# Name: user_message, Length: 2012, dtype: object

# %%
def user_and_message_splitter(text):
    parts = text.split(":")
    user = parts[0].strip()  # Get the user part and remove leading/trailing whitespaces
    message = parts[1].strip() if len(parts) > 1 else ''  # Get the message part or an empty string if not present
    return user, message


# Apply the function to 'user_message' and create new columns 'user' and 'message'
df[['user', 'message']] = pd.DataFrame(df['user_message'].apply(user_and_message_splitter).tolist())

# Display the DataFrame
# print(df)

# %%
df
# Out:
#                                            user_message                Date  \
# 0     Messages and calls are end-to-end encrypted. N... 2022-09-28 21:21:00
# 1                                       Guddu...: Hlo\n 2022-09-28 20:23:00
# 2                                      Khushilal: Hjr\n 2022-09-28 21:43:00
# 3                                   Khushilal: Vannue\n 2022-09-28 21:43:00
# 4                                        Khushilal: S\n 2022-09-28 21:43:00
# ...                                                 ...                 ...
# 2007                            Khushilal: party chai\n 2023-11-21 18:24:00
# 2008                                 Guddu...: Online\n 2023-11-21 18:26:00
# 2009                              Guddu...: Dhanyavad\n 2023-11-21 18:26:00
# 2010                             Khushilal: deu na ta\n 2023-11-21 18:43:00
# 2011                                    Khushilal: ..\n 2023-11-21 20:04:00
#
#                                                    user     message
# 0     Messages and calls are end-to-end encrypted. N...
# 1                                              Guddu...         Hlo
# 2                                             Khushilal         Hjr
# 3                                             Khushilal      Vannue
# 4                                             Khushilal           S
# ...                                                 ...         ...
# 2007                                          Khushilal  party chai
# 2008                                           Guddu...      Online
# 2009                                           Guddu...   Dhanyavad
# 2010                                          Khushilal   deu na ta
# 2011                                          Khushilal          ..
#
# [2012 rows x 4 columns]

# %%
df['user_message'][0]
# Out:
# 'Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n'

# %%
df=df.drop(columns='user_message')

# %%
df.head()
# Out:
#                  Date                                               user  \
# 0 2022-09-28 21:21:00  Messages and calls are end-to-end encrypted. N...
# 1 2022-09-28 20:23:00                                           Guddu...
# 2 2022-09-28 21:43:00                                          Khushilal
# 3 2022-09-28 21:43:00                                          Khushilal
# 4 2022-09-28 21:43:00                                          Khushilal
#
#   message
# 0
# 1     Hlo
# 2     Hjr
# 3  Vannue
# 4       S

# %%
df[df['message']=='']
# Out:
#                    Date                                               user  \
# 0   2022-09-28 21:21:00  Messages and calls are end-to-end encrypted. N...
# 172 2022-11-29 09:45:00  Your security code with Guddu... changed. Tap ...
# 173 2022-11-29 10:45:00  Your security code with Guddu... changed. Tap ...
# 174 2022-12-06 20:33:00  Your security code with Guddu... changed. Tap ...
# 175 2022-12-10 17:16:00  Your security code with Guddu... changed. Tap ...
# 176 2022-12-10 18:19:00  Your security code with Guddu... changed. Tap ...
# 177 2023-01-02 10:04:00  Your security code with Guddu... changed. Tap ...
# 178 2023-01-02 11:54:00  Your security code with Guddu... changed. Tap ...
# 179 2023-01-02 20:09:00  Your security code with Guddu... changed. Tap ...
# 180 2023-01-02 20:15:00  Your security code with Guddu... changed. Tap ...
# 181 2023-01-04 11:14:00  Your security code with Guddu... changed. Tap ...
# 182 2023-01-08 19:38:00  Your security code with Guddu... changed. Tap ...
# 183 2023-01-26 20:11:00  Your security code with Guddu... changed. Tap ...
# 467 2023-02-23 09:04:00  Your security code with Guddu... changed. Tap ...
# 468 2023-02-23 14:06:00  Your security code with Guddu... changed. Tap ...
# 469 2023-02-27 20:38:00  Your security code with Guddu... changed. Tap ...
# 479 2023-03-01 15:04:00  Your security code with Guddu... changed. Tap ...
# 480 2023-03-01 19:02:00  Your security code with Guddu... changed. Tap ...
# 481 2023-03-01 22:29:00  Your security code with Guddu... changed. Tap ...
# 486 2023-03-03 17:27:00  Your security code with Guddu... changed. Tap ...
# 618 2023-04-24 14:16:00  Your security code with Guddu... changed. Tap ...
# 619 2023-04-24 17:53:00  Your security code with Guddu... changed. Tap ...
# 685 2023-05-17 14:11:00  Your security code with Guddu... changed. Tap ...
#
#     message
# 0
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 467
# 468
# 469
# 479
# 480
# 481
# 486
# 618
# 619
# 685

# %%
df['message'].isnull().sum()
# Out:
# 0

# %%
df['Year']=df['Date'].dt.year

# %%
# if df['user']== 'Your security code with Guddu... changed. Tap to learn more.' and  df['user']=='Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.':

# %%
df['user'].replace(['Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.','Your security code with Guddu... changed. Tap to learn more.'],"Group_notification",inplace=True)

# %%
df['user'].unique()
# Out:
# array(['Group_notification', 'Guddu...', 'Khushilal'], dtype=object)

# %%
df['month_name']=df['Date'].dt.month_name()

# %%
df.sample(20)
# Out:
#                     Date       user  \
# 136  2022-11-19 15:53:00  Khushilal
# 731  2023-05-24 22:01:00  Khushilal
# 1242 2023-09-24 22:08:00  Khushilal
# 108  2022-10-04 20:55:00   Guddu...
# 440  2023-02-13 21:00:00   Guddu...
# 91   2022-10-04 20:49:00   Guddu...
# 80   2022-09-30 06:55:00   Guddu...
# 1007 2023-08-19 20:34:00   Guddu...
# 655  2023-04-27 14:03:00  Khushilal
# 1505 2023-10-28 20:45:00  Khushilal
# 1814 2023-11-04 22:25:00   Guddu...
# 883  2023-07-14 10:45:00   Guddu...
# 1509 2023-10-28 20:48:00   Guddu...
# 1029 2023-08-22 12:47:00  Khushilal
# 1960 2023-11-09 20:20:00  Khushilal
# 1246 2023-09-24 22:10:00  Khushilal
# 1878 2023-11-06 19:17:00  Khushilal
# 482  2023-03-02 19:46:00  Khushilal
# 1420 2023-10-18 14:01:00   Guddu...
# 1044 2023-08-24 06:49:00  Khushilal
#
#                                                 message  Year month_name
# 136                                               Guess  2022   November
# 731                                           Lagdai na  2023        May
# 1242                                          Galat bat  2023  September
# 108                         Tyo timi lai aafai tha hola  2022    October
# 440   Taso vye, Hotel jau na, serve garne le nai khu...  2023   February
# 91                       Tyo ta timi lai tha hunu parne  2022    October
# 80                                                Xaina  2022  September
# 1007                                             Tik xa  2023     August
# 655                                 Vana k vanna lagyau  2023      April
# 1505                               Apana he kat raha he  2023    October
# 1814                                          Khana aau  2023   November
# 883      Ma ka serious leko, tai ta ma ni vana khoje ko  2023       July
# 1509                                                Umm  2023    October
# 1029  kasto manxe ,bela bela ma sms garer garxa, ani...  2023     August
# 1960  Vanxau vane thik .khulduli hatla .aru ta kehi nai  2023   November
# 1246                                        K vanya jpt  2023  September
# 1878  nai tyahi ki tme sang koi dherai milen +2 ma t...  2023   November
# 482                                     <Media omitted>  2023      March
# 1420                                        Fire dragon  2023    October
# 1044                                    <Media omitted>  2023     August

# %%
df['day']=df['Date'].dt.day

# %%
df.head()
# Out:
#                  Date                user message  Year month_name  day
# 0 2022-09-28 21:21:00  Group_notification          2022  September   28
# 1 2022-09-28 20:23:00            Guddu...     Hlo  2022  September   28
# 2 2022-09-28 21:43:00           Khushilal     Hjr  2022  September   28
# 3 2022-09-28 21:43:00           Khushilal  Vannue  2022  September   28
# 4 2022-09-28 21:43:00           Khushilal       S  2022  September   28

# %%
df['Hour']=df['Date'].dt.hour
df
# Out:
#                     Date                user     message  Year month_name  \
# 0    2022-09-28 21:21:00  Group_notification              2022  September
# 1    2022-09-28 20:23:00            Guddu...         Hlo  2022  September
# 2    2022-09-28 21:43:00           Khushilal         Hjr  2022  September
# 3    2022-09-28 21:43:00           Khushilal      Vannue  2022  September
# 4    2022-09-28 21:43:00           Khushilal           S  2022  September
# ...                  ...                 ...         ...   ...        ...
# 2007 2023-11-21 18:24:00           Khushilal  party chai  2023   November
# 2008 2023-11-21 18:26:00            Guddu...      Online  2023   November
# 2009 2023-11-21 18:26:00            Guddu...   Dhanyavad  2023   November
# 2010 2023-11-21 18:43:00           Khushilal   deu na ta  2023   November
# 2011 2023-11-21 20:04:00           Khushilal          ..  2023   November
#
#       day  Hour
# 0      28    21
# 1      28    20
# 2      28    21
# 3      28    21
# 4      28    21
# ...   ...   ...
# 2007   21    18
# 2008   21    18
# 2009   21    18
# 2010   21    18
# 2011   21    20
#
# [2012 rows x 7 columns]

# %%
df['Minutes']=df['Date'].dt.minute
df
# Out:
#                     Date                user     message  Year month_name  \
# 0    2022-09-28 21:21:00  Group_notification              2022  September
# 1    2022-09-28 20:23:00            Guddu...         Hlo  2022  September
# 2    2022-09-28 21:43:00           Khushilal         Hjr  2022  September
# 3    2022-09-28 21:43:00           Khushilal      Vannue  2022  September
# 4    2022-09-28 21:43:00           Khushilal           S  2022  September
# ...                  ...                 ...         ...   ...        ...
# 2007 2023-11-21 18:24:00           Khushilal  party chai  2023   November
# 2008 2023-11-21 18:26:00            Guddu...      Online  2023   November
# 2009 2023-11-21 18:26:00            Guddu...   Dhanyavad  2023   November
# 2010 2023-11-21 18:43:00           Khushilal   deu na ta  2023   November
# 2011 2023-11-21 20:04:00           Khushilal          ..  2023   November
#
#       day  Hour  Minutes
# 0      28    21       21
# 1      28    20       23
# 2      28    21       43
# 3      28    21       43
# 4      28    21       43
# ...   ...   ...      ...
# 2007   21    18       24
# 2008   21    18       26
# 2009   21    18       26
# 2010   21    18       43
# 2011   21    20        4
#
# [2012 rows x 8 columns]

# %%
def text_preprocessing(text):
    #reading the tetx
    f=open(text,'r',encoding='utf-8')
    data=f.read()
    #pattern for splitting the message data and message
    #meaage
    pattern = r'\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s*[apmAPM]{2}\s-\s'
    message=re.split(pattern,data)[1:]
    #date
    date=re.findall(pattern,data)

    #making the dataframe
    data_dict={'user_message':message,"date":date}
    # print(data_dict)
    #data fraome
    df=pd.DataFrame(data_dict)

    # Attempt to convert the 'date' column to datetime or 24 hr form
    try:
        df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y, %I:%M %p - ')
    except ValueError as e:
        print(f"Error: {e}")


    # #user and their message splitter
    def user_and_message_splitter(text):
        parts = text.split(":")
        user = parts[0].strip()  # Get the user part and remove leading/trailing whitespaces
        message = parts[1].strip() if len(parts) > 1 else ''  # Get the message part or an empty string if not present
        return user, message


    # Apply the function to 'user_message' and create new columns 'user' and 'message'
    df[['User', 'Message']] = pd.DataFrame(df['user_message'].apply(user_and_message_splitter).tolist())

    #dropping the user_mesage
    df=df.drop(columns='user_message')

    
#splitting the date in year,mon.day,hr,min
    df['Year']=df['date'].dt.year
    df['Month']=df['date'].dt.month_name()
    df['Day']=df['date'].dt.day
    df['Hour']=df['date'].dt.hour
    df['Minute']=df['date'].dt.minute
    #renming
    
    df['User'].replace(['Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.','Your security code with Guddu... changed. Tap to learn more.'],"Group_notification",inplace=True)
    df.drop(columns='date',inplace=True)
 
#     #replacing  the emoji
#     def remove_emojis(text):
#         emoji_pattern = re.compile("["
#                                u"\U0001F600-\U0001F64F"  # emoticons
#                                u"\U0001F300-\U0001F5FF"  # symbols & pictographs
#                                u"\U0001F680-\U0001F6FF"  # transport & map symbols
#                                u"\U0001F700-\U0001F77F"  # alchemical symbols
#                                u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
#                                u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
#                                u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
#                                u"\U0001FA00-\U0001FA6F"  # Chess Symbols
#                                u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
#                                u"\U00002702-\U000027B0"  # Dingbats
#                                u"\U000024C2-\U0001F251" 
#                                "]+", flags=re.UNICODE)
#         return emoji_pattern.sub(r'', text)
    

#     df["Message"]=df['Message'].apply(remove_emojis)
    
    

    return df

# %%
final_df=text_preprocessing('WhatsApp_Chat_with_Guddu.txt')

# %%
final_df
# Out:
#                     User     Message  Year      Month  Day  Hour  Minute
# 0     Group_notification              2022  September   28    21      21
# 1               Guddu...         Hlo  2022  September   28    20      23
# 2              Khushilal         Hjr  2022  September   28    21      43
# 3              Khushilal      Vannue  2022  September   28    21      43
# 4              Khushilal           S  2022  September   28    21      43
# ...                  ...         ...   ...        ...  ...   ...     ...
# 2007           Khushilal  party chai  2023   November   21    18      24
# 2008            Guddu...      Online  2023   November   21    18      26
# 2009            Guddu...   Dhanyavad  2023   November   21    18      26
# 2010           Khushilal   deu na ta  2023   November   21    18      43
# 2011           Khushilal          ..  2023   November   21    20       4
#
# [2012 rows x 7 columns]

# %%
final_df[final_df['User']=="Guddu..."]
# Out:
#           User              Message  Year      Month  Day  Hour  Minute
# 1     Guddu...                  Hlo  2022  September   28    20      23
# 5     Guddu...                    ?  2022  September   29     6      33
# 6     Guddu...      <Media omitted>  2022  September   29    11      36
# 7     Guddu...      <Media omitted>  2022  September   29    11      37
# 8     Guddu...   Kun phone ramro xa  2022  September   29    11      37
# ...        ...                  ...   ...        ...  ...   ...     ...
# 2002  Guddu...  Aaj bd ko uplaxa ma  2023   November   21    18       8
# 2005  Guddu...          Ni tu ko ho  2023   November   21    18      11
# 2006  Guddu...                 Nitu  2023   November   21    18      11
# 2008  Guddu...               Online  2023   November   21    18      26
# 2009  Guddu...            Dhanyavad  2023   November   21    18      26
#
# [943 rows x 7 columns]

# %%
#checking the no. of word
word=[]
for message in final_df['Message']:
   word.extend(message.split(" "))

# %%
# !pip install urlextract

# %%
len(word)
# Out:
# 7667

# %%
final_df
# Out:
#                     User     Message  Year      Month  Day  Hour  Minute
# 0     Group_notification              2022  September   28    21      21
# 1               Guddu...         Hlo  2022  September   28    20      23
# 2              Khushilal         Hjr  2022  September   28    21      43
# 3              Khushilal      Vannue  2022  September   28    21      43
# 4              Khushilal           S  2022  September   28    21      43
# ...                  ...         ...   ...        ...  ...   ...     ...
# 2007           Khushilal  party chai  2023   November   21    18      24
# 2008            Guddu...      Online  2023   November   21    18      26
# 2009            Guddu...   Dhanyavad  2023   November   21    18      26
# 2010           Khushilal   deu na ta  2023   November   21    18      43
# 2011           Khushilal          ..  2023   November   21    20       4
#
# [2012 rows x 7 columns]

# %%
user_df=final_df['User'].value_counts().head()

# %%
import matplotlib.pyplot as plt

# %%
name_user=user_df.index
count=user_df.values

# %%
plt.bar(name_user,count)
plt.xticks(rotation='vertical')
plt.show()

# %%
user_df=round((final_df['User'].value_counts())/(final_df.shape[0])*100,2).reset_index()
user_df.rename(columns={'index':"Name","User":"Percentage"})
# Out:
#                  Name  Percentage
# 0           Khushilal       51.99
# 1            Guddu...       46.87
# 2  Group_notification        1.14

# %%
user_df
# Out:
#                 index   User
# 0           Khushilal  51.99
# 1            Guddu...  46.87
# 2  Group_notification   1.14

# %% [markdown]
# # finding the top 20 word used induvidual or in group

# %%
# final_df
#removing the group notification
final_df=final_df[final_df['User']!="Group_notification"]
#filtering the medial ommitted
final_df=final_df[final_df['Message']!='<Media omitted>']

# %%
from nltk.corpus import stopwords

nepali_stopwords = stopwords.words("nepali")
english_stopwords = stopwords.words("english")

# %%
nepali_stopwords
# Out:
# ['छ',
#  'र',
#  'पनि',
#  'छन्',
#  'लागि',
#  'भएको',
#  'गरेको',
#  'भने',
#  'गर्न',
#  'गर्ने',
#  'हो',
#  'तथा',
#  'यो',
#  'रहेको',
#  'उनले',
#  'थियो',
#  'हुने',
#  'गरेका',
#  'थिए',
#  'गर्दै',
#  'तर',
#  'नै',
#  'को',
#  'मा',
#  'हुन्',
#  'भन्ने',
#  'हुन',
#  'गरी',
#  'त',
#  'हुन्छ',
#  'अब',
#  'के',
#  'रहेका',
#  'गरेर',
#  'छैन',
#  'दिए',
#  'भए',
#  'यस',
#  'ले',
#  'गर्नु',
#  'औं',
#  'सो',
#  'त्यो',
#  'कि',
#  'जुन',
#  'यी',
#  'का',
#  'गरि',
#  'ती',
#  'न',
#  'छु',
#  'छौं',
#  'लाई',
#  'नि',
#  'उप',
#  'अक्सर',
#  'आदि',
#  'कसरी',
#  'क्रमशः',
#  'चाले',
#  'अगाडी',
#  'अझै',
#  'अनुसार',
#  'अन्तर्गत',
#  'अन्य',
#  'अन्यत्र',
#  'अन्यथा',
#  'अरु',
#  'अरुलाई',
#  'अर्को',
#  'अर्थात',
#  'अर्थात्',
#  'अलग',
#  'आए',
#  'आजको',
#  'ओठ',
#  'आत्म',
#  'आफू',
#  'आफूलाई',
#  'आफ्नै',
#  'आफ्नो',
#  'आयो',
#  'उदाहरण',
#  'उनको',
#  'उहालाई',
#  'एउटै',
#  'एक',
#  'एकदम',
#  'कतै',
#  'कम से कम',
#  'कसै',
#  'कसैले',
#  'कहाँबाट',
#  'कहिलेकाहीं',
#  'का',
#  'किन',
#  'किनभने',
#  'कुनै',
#  'कुरा',
#  'कृपया',
#  'केही',
#  'कोही',
#  'गए',
#  'गरौं',
#  'गर्छ',
#  'गर्छु',
#  'गर्नुपर्छ',
#  'गयौ',
#  'गैर',
#  'चार',
#  'चाहनुहुन्छ',
#  'चाहन्छु',
#  'चाहिए',
#  'छू',
#  'जताततै',
#  'जब',
#  'जबकि',
#  'जसको',
#  'जसबाट',
#  'जसमा',
#  'जसलाई',
#  'जसले',
#  'जस्तै',
#  'जस्तो',
#  'जस्तोसुकै',
#  'जहाँ',
#  'जान',
#  'जाहिर',
#  'जे',
#  'जो',
#  'ठीक',
#  'तत्काल',
#  'तदनुसार',
#  'तपाईको',
#  'तपाई',
#  'पर्याप्त',
#  'पहिले',
#  'पहिलो',
#  'पहिल्यै',
#  'पाँच',
#  'पाँचौं',
#  'तल',
#  'तापनी',
#  'तिनी',
#  'तिनीहरू',
#  'तिनीहरुको',
#  'तिनिहरुलाई',
#  'तिमी',
#  'तिर',
#  'तीन',
#  'तुरुन्तै',
#  'तेस्रो',
#  'तेस्कारण',
#  'पूर्व',
#  'प्रति',
#  'प्रतेक',
#  'प्लस',
#  'फेरी',
#  'बने',
#  'त्सपछि',
#  'त्सैले',
#  'त्यहाँ',
#  'थिएन',
#  'दिनुभएको',
#  'दिनुहुन्छ',
#  'दुई',
#  'देखि',
#  'बरु',
#  'बारे',
#  'बाहिर',
#  'देखिन्छ',
#  'देखियो',
#  'देखे',
#  'देखेको',
#  'देखेर',
#  'दोस्रो',
#  'धेरै',
#  'नजिकै',
#  'नत्र',
#  'नयाँ',
#  'निम्ति',
#  'बाहेक',
#  'बीच',
#  'बीचमा',
#  'भन',
#  'निम्न',
#  'निम्नानुसार',
#  'निर्दिष्ट',
#  'नौ',
#  'पक्का',
#  'पक्कै',
#  'पछि',
#  'पछिल्लो',
#  'पटक',
#  'पर्छ',
#  'पर्थ्यो',
#  'भन्छन्',
#  'भन्',
#  'भन्छु',
#  'भन्दा',
#  'भन्नुभयो',
#  'भर',
#  'भित्र',
#  'भित्री',
#  'म',
#  'मलाई',
#  'मात्र',
#  'माथि',
#  'मुख्य',
#  'मेरो',
#  'यति',
#  'यथोचित',
#  'यदि',
#  'यद्यपि',
#  'यसको',
#  'यसपछि',
#  'यसबाहेक',
#  'यसरी',
#  'यसो',
#  'यस्तो',
#  'यहाँ',
#  'यहाँसम्म',
#  'या',
#  'रही',
#  'राखे',
#  'राख्छ',
#  'राम्रो',
#  'रूप',
#  'लगभग',
#  'वरीपरी',
#  'वास्तवमा',
#  'बिरुद्ध',
#  'बिशेष',
#  'सायद',
#  'शायद',
#  'संग',
#  'संगै',
#  'सक्छ',
#  'सट्टा',
#  'सधै',
#  'सबै',
#  'सबैलाई',
#  'समय',
#  'सम्भव',
#  'सम्म',
#  'सही',
#  'साँच्चै',
#  'सात',
#  'साथ',
#  'साथै',
#  'सारा',
#  'सोही',
#  'स्पष्ट',
#  'हरे',
#  'हरेक']

# %%
nepanglish_stopword=['Cha','Ra','Pani','Chhan',"Lagi",'Bhaeko','Gareko','Bhane','Garna','Ho','Tatha','Yo','raheko','unale','thiyo','hune','thiye','gardai','tar','nai','ko','maa','hunu','bhanne','gari','ta','hunxa','aba','k','raheko','garer','chhain','Hlo','K']

# %%
total_stopword=nepali_stopwords+english_stopwords+nepanglish_stopword
# total_stopword

total_stopword
# Out:
# ['छ',
#  'र',
#  'पनि',
#  'छन्',
#  'लागि',
#  'भएको',
#  'गरेको',
#  'भने',
#  'गर्न',
#  'गर्ने',
#  'हो',
#  'तथा',
#  'यो',
#  'रहेको',
#  'उनले',
#  'थियो',
#  'हुने',
#  'गरेका',
#  'थिए',
#  'गर्दै',
#  'तर',
#  'नै',
#  'को',
#  'मा',
#  'हुन्',
#  'भन्ने',
#  'हुन',
#  'गरी',
#  'त',
#  'हुन्छ',
#  'अब',
#  'के',
#  'रहेका',
#  'गरेर',
#  'छैन',
#  'दिए',
#  'भए',
#  'यस',
#  'ले',
#  'गर्नु',
#  'औं',
#  'सो',
#  'त्यो',
#  'कि',
#  'जुन',
#  'यी',
#  'का',
#  'गरि',
#  'ती',
#  'न',
#  'छु',
#  'छौं',
#  'लाई',
#  'नि',
#  'उप',
#  'अक्सर',
#  'आदि',
#  'कसरी',
#  'क्रमशः',
#  'चाले',
#  'अगाडी',
#  'अझै',
#  'अनुसार',
#  'अन्तर्गत',
#  'अन्य',
#  'अन्यत्र',
#  'अन्यथा',
#  'अरु',
#  'अरुलाई',
#  'अर्को',
#  'अर्थात',
#  'अर्थात्',
#  'अलग',
#  'आए',
#  'आजको',
#  'ओठ',
#  'आत्म',
#  'आफू',
#  'आफूलाई',
#  'आफ्नै',
#  'आफ्नो',
#  'आयो',
#  'उदाहरण',
#  'उनको',
#  'उहालाई',
#  'एउटै',
#  'एक',
#  'एकदम',
#  'कतै',
#  'कम से कम',
#  'कसै',
#  'कसैले',
#  'कहाँबाट',
#  'कहिलेकाहीं',
#  'का',
#  'किन',
#  'किनभने',
#  'कुनै',
#  'कुरा',
#  'कृपया',
#  'केही',
#  'कोही',
#  'गए',
#  'गरौं',
#  'गर्छ',
#  'गर्छु',
#  'गर्नुपर्छ',
#  'गयौ',
#  'गैर',
#  'चार',
#  'चाहनुहुन्छ',
#  'चाहन्छु',
#  'चाहिए',
#  'छू',
#  'जताततै',
#  'जब',
#  'जबकि',
#  'जसको',
#  'जसबाट',
#  'जसमा',
#  'जसलाई',
#  'जसले',
#  'जस्तै',
#  'जस्तो',
#  'जस्तोसुकै',
#  'जहाँ',
#  'जान',
#  'जाहिर',
#  'जे',
#  'जो',
#  'ठीक',
#  'तत्काल',
#  'तदनुसार',
#  'तपाईको',
#  'तपाई',
#  'पर्याप्त',
#  'पहिले',
#  'पहिलो',
#  'पहिल्यै',
#  'पाँच',
#  'पाँचौं',
#  'तल',
#  'तापनी',
#  'तिनी',
#  'तिनीहरू',
#  'तिनीहरुको',
#  'तिनिहरुलाई',
#  'तिमी',
#  'तिर',
#  'तीन',
#  'तुरुन्तै',
#  'तेस्रो',
#  'तेस्कारण',
#  'पूर्व',
#  'प्रति',
#  'प्रतेक',
#  'प्लस',
#  'फेरी',
#  'बने',
#  'त्सपछि',
#  'त्सैले',
#  'त्यहाँ',
#  'थिएन',
#  'दिनुभएको',
#  'दिनुहुन्छ',
#  'दुई',
#  'देखि',
#  'बरु',
#  'बारे',
#  'बाहिर',
#  'देखिन्छ',
#  'देखियो',
#  'देखे',
#  'देखेको',
#  'देखेर',
#  'दोस्रो',
#  'धेरै',
#  'नजिकै',
#  'नत्र',
#  'नयाँ',
#  'निम्ति',
#  'बाहेक',
#  'बीच',
#  'बीचमा',
#  'भन',
#  'निम्न',
#  'निम्नानुसार',
#  'निर्दिष्ट',
#  'नौ',
#  'पक्का',
#  'पक्कै',
#  'पछि',
#  'पछिल्लो',
#  'पटक',
#  'पर्छ',
#  'पर्थ्यो',
#  'भन्छन्',
#  'भन्',
#  'भन्छु',
#  'भन्दा',
#  'भन्नुभयो',
#  'भर',
#  'भित्र',
#  'भित्री',
#  'म',
#  'मलाई',
#  'मात्र',
#  'माथि',
#  'मुख्य',
#  'मेरो',
#  'यति',
#  'यथोचित',
#  'यदि',
#  'यद्यपि',
#  'यसको',
#  'यसपछि',
#  'यसबाहेक',
#  'यसरी',
#  'यसो',
#  'यस्तो',
#  'यहाँ',
#  'यहाँसम्म',
#  'या',
#  'रही',
#  'राखे',
#  'राख्छ',
#  'राम्रो',
#  'रूप',
#  'लगभग',
#  'वरीपरी',
#  'वास्तवमा',
#  'बिरुद्ध',
#  'बिशेष',
#  'सायद',
#  'शायद',
#  'संग',
#  'संगै',
#  'सक्छ',
#  'सट्टा',
#  'सधै',
#  'सबै',
#  'सबैलाई',
#  'समय',
#  'सम्भव',
#  'सम्म',
#  'सही',
#  'साँच्चै',
#  'सात',
#  'साथ',
#  'साथै',
#  'सारा',
#  'सोही',
#  'स्पष्ट',
#  'हरे',
#  'हरेक',
#  'i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'Cha',
#  'Ra',
#  'Pani',
#  'Chhan',
#  'Lagi',
#  'Bhaeko',
#  'Gareko',
#  'Bhane',
#  'Garna',
#  'Ho',
#  'Tatha',
#  'Yo',
#  'raheko',
#  'unale',
#  'thiyo',
#  'hune',
#  'thiye',
#  'gardai',
#  'tar',
#  'nai',
#  'ko',
#  'maa',
#  'hunu',
#  'bhanne',
#  'gari',
#  'ta',
#  'hunxa',
#  'aba',
#  'k',
#  'raheko',
#  'garer',
#  'chhain',
#  'Hlo',
#  'K']

# %%
import string
string
# Out:
# <module 'string' from 'C:\\Users\\Acer\\anaconda3\\lib\\string.py'>

# %%
word_list=[]
for word in final_df['Message']:
    if word not in total_stopword:
        word_list.extend(word.split( ))
        

word_list
# Out:
# ['Hjr',
#  'Vannue',
#  'S',
#  '?',
#  'Kun',
#  'phone',
#  'ramro',
#  'xa',
#  'Kasko',
#  'lagi',
#  'Kinna',
#  'lago',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'Xito',
#  'वन',
#  'Vana',
#  'Dashai',
#  'मा',
#  'नी',
#  'कति',
#  'busy',
#  'hune',
#  'garxau',
#  'Ma',
#  'configure',
#  'gare',
#  'vanxu',
#  'la',
#  'Yaha',
#  'ek',
#  'mahina',
#  'dekhi',
#  'mobli',
#  'banda',
#  'thyo',
#  'ani',
#  'ali',
#  'sms',
#  'garna',
#  'pako',
#  'xu',
#  'so',
#  'Kina',
#  'Ka',
#  'xau',
#  'ra',
#  'La',
#  'on',
#  'thw',
#  'evaluation',
#  'of',
#  'the',
#  'featuee',
#  'and',
#  'public',
#  'review',
#  'Real',
#  'me',
#  'be',
#  'the',
#  'best',
#  'Aajha',
#  'phone',
#  'haru',
#  'ko',
#  'ni',
#  'name',
#  'vana',
#  'na',
#  '14',
#  'to',
#  '18k',
#  'ko',
#  'range',
#  'ra',
#  'IC',
#  'Ipjone',
#  'leu',
#  'ramro',
#  'hunxa',
#  'Tyaso',
#  'vaye',
#  'Lidi',
#  'na',
#  'Kasko',
#  'lagi',
#  'ho',
#  'van',
#  'ma',
#  'tyaanusar',
#  'herxu',
#  'La',
#  'mero',
#  'lagi,',
#  'aaba',
#  'ramari',
#  'hera',
#  'aani',
#  'vana',
#  'Sachaii',
#  'ho',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'Umm',
#  'k',
#  'Redmi',
#  'vadna',
#  'real',
#  'me',
#  'ramro',
#  'haii',
#  'Aagadi',
#  'send',
#  'gare',
#  'ko',
#  'tik',
#  'xa',
#  'ni',
#  'Natra',
#  'real',
#  'me',
#  'mai',
#  'aaru',
#  'ni',
#  'hera',
#  'na',
#  'La',
#  'yo',
#  'dutai',
#  'ma',
#  'vandau',
#  'ta',
#  'Yo',
#  'ani',
#  'lasto',
#  'ko',
#  'ma',
#  'euta',
#  'leu',
#  'Tai',
#  'duta',
#  'bata',
#  'Aauta',
#  'select',
#  'garna',
#  'vane',
#  'Quick',
#  'charging',
#  'hera',
#  'ta',
#  'Tyo',
#  'ni',
#  'maile',
#  'nai',
#  'garnu',
#  'parne',
#  'ho',
#  'Gardau',
#  'na',
#  'k',
#  'vayo',
#  'Free',
#  'maii',
#  'Aani',
#  'k',
#  'chaiyoo🤣🤣',
#  'K',
#  'vayo',
#  'Last',
#  'ko',
#  'thik',
#  'xa',
#  'Feature',
#  'aautai',
#  'here',
#  'ma',
#  'size',
#  'thulo',
#  'dutai',
#  'ko',
#  'compare',
#  'ma',
#  'Ali',
#  'ali',
#  'farak',
#  'xa',
#  'K',
#  'xa',
#  'aajha',
#  'Euta',
#  '4g',
#  'arko',
#  '5',
#  'g',
#  'xa',
#  'Umm',
#  'tyo',
#  'ni',
#  'xa',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'Thank',
#  'u',
#  'vandi',
#  'na',
#  'K',
#  'vayo',
#  'vaneko',
#  'thank',
#  'you',
#  'return',
#  'hudai',
#  'na',
#  'Clear',
#  'xaina',
#  'kehi',
#  'bujhi',
#  'ra',
#  'xaina',
#  'J',
#  'hos',
#  'lasto',
#  'wala',
#  'thik',
#  'xq',
#  'tyati',
#  'ho',
#  'Seen',
#  'garyo',
#  'vane,',
#  'return',
#  'garnu',
#  'parxa',
#  'mero',
#  'Kin',
#  'retur',
#  'mageko',
#  'Kam',
#  'vayesi',
#  'ta',
#  'repl',
#  'nai',
#  'banda',
#  'hudo',
#  'rahex',
#  'haii',
#  'Sab',
#  'manxe',
#  'yastaii',
#  'xa',
#  'yo',
#  'duniya',
#  'jasto',
#  'lago...',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'Timi',
#  'ka',
#  'xau',
#  'Aaile',
#  'स्वार्थी',
#  'भए',
#  'र',
#  'la',
#  '11',
#  'baje',
#  'garam',
#  'la',
#  'kura',
#  'la',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'K',
#  'vayo',
#  'ki',
#  'a',
#  'na',
#  'de',
#  'ko',
#  'reply',
#  'Ho',
#  'ra',
#  'Special',
#  'hune',
#  'bala',
#  'sathi',
#  'sang',
#  'kura',
#  'garthe',
#  'Ko',
#  'xa',
#  'ra',
#  'Xa',
#  'ni',
#  'koii',
#  'That',
#  'confedential',
#  'Vana',
#  'mildai',
#  'na',
#  'Vanamla',
#  'Kin',
#  'yau',
#  'mobile',
#  'Xaina',
#  'Tasto',
#  'tyo',
#  'vane',
#  'aaile',
#  'kina',
#  'vane',
#  'ko',
#  'Aaba',
#  'xito',
#  'vani',
#  'hal',
#  'Hllo',
#  'Hjr',
#  'Hloo',
#  'Voli',
#  'kaha',
#  'mela',
#  'jane',
#  'bchar',
#  'xa',
#  'Ghar',
#  'ma',
#  'Bidesh',
#  'bata',
#  'laiye',
#  'ko',
#  'phone',
#  'lai',
#  'darta',
#  'garaunu',
#  'parxa',
#  'ki',
#  'nai',
#  'Purnima',
#  'heri',
#  'heri',
#  'reply',
#  'dine',
#  'manxe',
#  'Aja',
#  'sayad',
#  'feri',
#  'purnima',
#  'ho',
#  'ki',
#  'kaso',
#  'Tyo',
#  'ta',
#  'timi',
#  'lai',
#  'tha',
#  'hunu',
#  'parne',
#  'Ho',
#  'aja',
#  'ho',
#  'Tyo',
#  'ta',
#  'use',
#  'gare',
#  'lai',
#  'tha',
#  'hola',
#  'ni',
#  'Reply',
#  'didanua',
#  'tme',
#  'ani',
#  'malai',
#  'vanxa',
#  'manxe',
#  'chahi',
#  'Kasto',
#  'duniya',
#  'ayoo',
#  'Tyasko',
#  'lagi',
#  'check',
#  'garnu',
#  'para',
#  'Registre',
#  'vako',
#  'xa',
#  'ki',
#  'nai',
#  'using',
#  'imei',
#  'number',
#  'checking',
#  'Kaha',
#  'vago',
#  '....',
#  'Dunya',
#  'hoina,',
#  'timi',
#  'Duniya',
#  'lai',
#  'kina',
#  'dos',
#  'dinxau',
#  'Bujhi',
#  'na',
#  'Kaslai',
#  'dos',
#  'diu',
#  'ta',
#  'vanna',
#  'Kasari',
#  ',',
#  'Ka',
#  'zau',
#  'aaile',
#  'Xau',
#  'Aafai',
#  'lai😂',
#  'Kasri',
#  'Tyo',
#  'timi',
#  'lai',
#  'aafai',
#  'tha',
#  'hola',
#  'https',
#  'https',
#  'Tala',
#  'ko',
#  'link',
#  'ma',
#  'gayer',
#  'IMEI',
#  'NO.',
#  'HALNE',
#  'Ani',
#  'k',
#  'hudai',
#  'xa',
#  'aja',
#  'kal',
#  'K',
#  'na',
#  'k😔',
#  'Bujhyauu',
#  'Mero',
#  'vagya',
#  'kharab',
#  'xa',
#  'Bahut',
#  'https',
#  'Yasma',
#  'kunqi',
#  'mandi',
#  'foto',
#  'send',
#  'gara',
#  'la',
#  '??',
#  'Click',
#  'gara',
#  'anii',
#  'thaha',
#  'Pauxauuu',
#  'Mandi?',
#  '?',
#  'Tyo',
#  'page',
#  'ko',
#  'form',
#  'ma',
#  'rakhna',
#  'https',
#  'You',
#  'deleted',
#  'this',
#  'message',
#  'K',
#  'xa',
#  'yo',
#  'null',
#  'Timi',
#  'k',
#  'ma',
#  'parxau',
#  'K',
#  'ma',
#  'rakhxau',
#  'tyasmai',
#  'Tasto',
#  'ni',
#  'hunxa🤣🤣',
#  'K',
#  'ma',
#  'xau,',
#  'la',
#  'vandau',
#  'K',
#  'lagxa',
#  'tme',
#  'lai',
#  'Tha,',
#  'na',
#  'vaye',
#  'ra',
#  'sode,',
#  'natra',
#  'ka',
#  'sodhu',
#  'ma',
#  'Guess',
#  'Tasto',
#  'kaam',
#  'gardi',
#  'na',
#  'ma,',
#  'la',
#  'vandau',
#  'Ag',
#  'Kaile',
#  'dekhi',
#  'Khoi',
#  'K',
#  'xa',
#  'giriraj',
#  'ko',
#  'khabar',
#  'uta',
#  'tir',
#  'Kaha',
#  'harayau',
#  'Kata',
#  'na',
#  'kata',
#  'Kin',
#  'k',
#  'vo',
#  'ra',
#  'Independent',
#  'ko',
#  'dekhayen',
#  'Competation',
#  '2',
#  'bich',
#  'matra',
#  'xa',
#  ',',
#  'independent',
#  'tharai',
#  'paxadi',
#  'Timro',
#  'bichar',
#  'ma',
#  'ko',
#  'jite',
#  'ko',
#  'ramro',
#  'Timi',
#  'k',
#  'ma',
#  'vote',
#  'diye',
#  'tyo',
#  'Sabai',
#  'afano',
#  'vision',
#  'ra',
#  'agenda',
#  'le',
#  'ako',
#  'hunxa',
#  'aba',
#  'heram',
#  'Kati',
#  'baki',
#  'x',
#  'counting',
#  'hune',
#  'And',
#  'chitwan',
#  'ko',
#  'k',
#  'xa',
#  'update',
#  'Tha',
#  'vaye',
#  'na',
#  'Mero',
#  'bicahr',
#  'ma',
#  'tme',
#  'jiteko',
#  'vaye',
#  'ramro',
#  'ni',
#  'Kina',
#  'ni',
#  'Ma',
#  'k',
#  'gartye',
#  'Ma',
#  'part',
#  'Khan',
#  'pauthe',
#  'so',
#  'Ma',
#  'birgunj',
#  'janu',
#  'parne',
#  'xa',
#  'Lovi',
#  'manxe',
#  'Kina',
#  'Vetnu',
#  'xa',
#  'ek',
#  'jana',
#  'lai',
#  'Kaslai',
#  'Xa',
#  'Ko',
#  'Vana',
#  'mildai',
#  'na',
#  'Nai',
#  'Ok',
#  'Vanamla',
#  'Suitable',
#  'time',
#  'ko',
#  'wait',
#  'gara',
#  'Vanu',
#  'xa',
#  'vane',
#  'aaile',
#  'vanA,',
#  'natra',
#  'tasto',
#  'ma',
#  'wait',
#  'gare',
#  'ra',
#  'basne',
#  'khal',
#  'ki',
#  'xuina',
#  'Ok',
#  'n',
#  'basa',
#  'Hllo',
#  'Hjr',
#  'K',
#  'xa',
#  'khabar',
#  'Cll',
#  'garu',
#  'Tik',
#  'vanoo',
#  'ki',
#  'bekar',
#  'tha',
#  'xaina',
#  'Lekhna',
#  'jhyau',
#  'lagxa',
#  'Voli',
#  'exam🥺🥺',
#  'Numerical',
#  'gardau',
#  'na',
#  'Call',
#  'garxu',
#  'la',
#  'ahile',
#  '5min',
#  'ta',
#  'ho',
#  'Kun',
#  'ko',
#  'ho',
#  'Kehi',
#  'bises',
#  'xa',
#  'ra',
#  'Genetic',
#  'Vanamla',
#  'La',
#  'la',
#  '2',
#  'min',
#  'Sathi',
#  'haru',
#  'padhi',
#  'ra',
#  'xa',
#  'disturb',
#  'hunxa',
#  'Missed',
#  'voice',
#  'call',
#  'K',
#  'vo',
#  'ta',
#  'Thank',
#  'u,',
#  'buttimi',
#  'lai',
#  'kasari',
#  'tha',
#  'vayo',
#  'ma',
#  'patlu',
#  'xu',
#  'Intelligent',
#  'manxe',
#  'But',
#  'ma',
#  'motaxu',
#  'Juoo',
#  'motaye',
#  'si',
#  'sound',
#  'ni',
#  'motaooxa',
#  'ki',
#  'kaso',
#  'Ma',
#  'motaoodi',
#  'na',
#  'kaile',
#  'Jasto',
#  'lagxa',
#  'malai',
#  'La',
#  'exam',
#  'sakesi',
#  'sms',
#  'gara......',
#  'Ahile',
#  'gaye',
#  'Huss',
#  'Guddu',
#  'https',
#  'K',
#  'ko',
#  'link',
#  'ho',
#  'Jasto',
#  'lagi',
#  'ra',
#  'xa',
#  'herekai',
#  'xaina',
#  'tastai',
#  'Yasto',
#  'link',
#  'haru',
#  'na',
#  'open',
#  'gara',
#  'hacker',
#  'haru',
#  'phone',
#  'hack',
#  'garidin',
#  'sakxa',
#  'Sachaii',
#  'dekhya',
#  'xaiii',
#  'Sachai',
#  'yasto',
#  'hunxa',
#  'Hoina',
#  'ma',
#  'yo',
#  'Facebook',
#  'ko',
#  'video',
#  'ko',
#  'link',
#  'send',
#  'gare',
#  'ho',
#  'Exam',
#  'haru',
#  'ta',
#  'xaina',
#  'ni',
#  'timro',
#  'aaile',
#  'Tmro',
#  'xa',
#  'hoin',
#  'Exam',
#  'Padhne',
#  'afu',
#  'xau',
#  'ani',
#  'malai',
#  'vanxau',
#  'hyat',
#  'Xa',
#  'Na',
#  'padhe',
#  'ra',
#  'ta',
#  'sms',
#  'gare',
#  'ho',
#  'Ma',
#  'Kura',
#  'garnu',
#  'xa',
#  'vane',
#  'cll',
#  'gara',
#  'yo',
#  'typing',
#  'jhau',
#  'lagxa',
#  'haiii',
#  'Yati',
#  'sama',
#  'ko',
#  'aalxi',
#  'kaile',
#  'dekhi',
#  'https',
#  'https',
#  'https',
#  'kin',
#  'pathako',
#  'malai',
#  'yo',
#  'Timi',
#  'haru',
#  'ko',
#  'junior',
#  'aai',
#  'sake',
#  'hola',
#  'hsi',
#  'Pida',
#  'buje',
#  'ra🤣🤣',
#  'K',
#  'ko',
#  'tarkari',
#  'ho',
#  'Kati',
#  'oil',
#  'khanxau',
#  'Bujha',
#  'afaii',
#  'Kukhura',
#  'Dukha',
#  'xa',
#  'ni',
#  'Tai',
#  'dukkha',
#  'bujhe',
#  'ra',
#  'ta',
#  'patha',
#  'ko',
#  'Yasto',
#  'vane',
#  'lai',
#  'forward',
#  'gardinu',
#  'Yatika',
#  'experince',
#  'kasri',
#  'vayauuu',
#  'Thanks',
#  'dukha',
#  'bujheko',
#  'mq',
#  'Ya',
#  'exam',
#  'le',
#  'ramri',
#  'pelya',
#  'xa',
#  'ani',
#  'k',
#  'junior',
#  'na',
#  'senior',
#  'Sathi',
#  'haru',
#  'ko',
#  'pida',
#  'deke',
#  'ra',
#  'aafai',
#  'Mainly',
#  'u',
#  'Tme',
#  'malai',
#  'k',
#  'samjheko',
#  'ma',
#  'tyasto',
#  'mnxe',
#  'lagiraxu',
#  'ra',
#  'Tyati',
#  'samma',
#  'ko',
#  'kharab',
#  'xuin',
#  'oooo',
#  'Jati',
#  'man',
#  'lago',
#  'tyati',
#  'hloo',
#  'kaha',
#  'vagyau',
#  'Udi',
#  'saki',
#  'thye',
#  'Timi',
#  'dance',
#  'gari',
#  'ra',
#  'xau',
#  'vane',
#  'vhane,',
#  'biswas',
#  'vai',
#  'ra',
#  'xaina',
#  'k',
#  'Tyo',
#  'ni',
#  'jab',
#  'lagane',
#  'lu',
#  'jab',
#  'libistk🤣🤣🤣',
#  'sachaii',
#  'tme',
#  'lai',
#  'jhuto',
#  'lagya',
#  'thyo',
#  'Umm',
#  'kasailai',
#  'na',
#  'pathaunu',
#  'haii',
#  'la',
#  'Saraswati',
#  'vagwan',
#  'ko',
#  'aagadi',
#  'ma',
#  'banner',
#  'rakhe',
#  'ra',
#  'Yasto',
#  'yasto',
#  'geet',
#  'ma',
#  'dance',
#  'gardai',
#  'Ma',
#  'ta',
#  'pathai',
#  'sake',
#  'Mero',
#  'ma',
#  'kehi',
#  'send',
#  'garna',
#  'bitikai',
#  ...]

# %%
#removing the stop word

# %%
from wordcloud import WordCloud
wc=WordCloud(width=500,height=500,min_font_size=10,background_color='black')
df_wc=wc.generate(final_df['Message'].str.cat(sep=" "))
plt.imshow(df_wc)
plt.show()

# %%
from collections import Counter

# %%
Counter(word_list)
# Out:
# Counter({'Hjr': 5,
#          'Vannue': 1,
#          'S': 2,
#          '?': 25,
#          'Kun': 10,
#          'phone': 11,
#          'ramro': 16,
#          'xa': 145,
#          'Kasko': 9,
#          'lagi': 11,
#          'Kinna': 1,
#          'lago': 7,
#          'This': 16,
#          'message': 27,
#          'was': 16,
#          'deleted': 25,
#          'Xito': 1,
#          'वन': 1,
#          'Vana': 28,
#          'Dashai': 1,
#          'मा': 1,
#          'नी': 1,
#          'कति': 1,
#          'busy': 5,
#          'hune': 6,
#          'garxau': 5,
#          'Ma': 33,
#          'configure': 1,
#          'gare': 14,
#          'vanxu': 7,
#          'la': 30,
#          'Yaha': 2,
#          'ek': 7,
#          'mahina': 1,
#          'dekhi': 13,
#          'mobli': 1,
#          'banda': 6,
#          'thyo': 11,
#          'ani': 15,
#          'ali': 3,
#          'sms': 17,
#          'garna': 12,
#          'pako': 2,
#          'xu': 22,
#          'so': 5,
#          'Kina': 21,
#          'Ka': 6,
#          'xau': 29,
#          'ra': 125,
#          'La': 36,
#          'on': 1,
#          'thw': 1,
#          'evaluation': 1,
#          'of': 2,
#          'the': 10,
#          'featuee': 1,
#          'and': 3,
#          'public': 1,
#          'review': 1,
#          'Real': 1,
#          'me': 18,
#          'be': 2,
#          'best': 3,
#          'Aajha': 6,
#          'haru': 21,
#          'ko': 108,
#          'ni': 99,
#          'name': 4,
#          'vana': 36,
#          'na': 133,
#          '14': 1,
#          'to': 32,
#          '18k': 1,
#          'range': 1,
#          'IC': 1,
#          'Ipjone': 1,
#          'leu': 3,
#          'hunxa': 22,
#          'Tyaso': 3,
#          'vaye': 29,
#          'Lidi': 1,
#          'ho': 77,
#          'van': 1,
#          'ma': 119,
#          'tyaanusar': 1,
#          'herxu': 2,
#          'mero': 8,
#          'lagi,': 1,
#          'aaba': 10,
#          'ramari': 1,
#          'hera': 5,
#          'aani': 10,
#          'Sachaii': 4,
#          'Umm': 28,
#          'k': 90,
#          'Redmi': 1,
#          'vadna': 1,
#          'real': 4,
#          'haii': 7,
#          'Aagadi': 2,
#          'send': 10,
#          'tik': 3,
#          'Natra': 7,
#          'mai': 6,
#          'aaru': 2,
#          'yo': 22,
#          'dutai': 2,
#          'vandau': 3,
#          'ta': 77,
#          'Yo': 11,
#          'lasto': 3,
#          'euta': 3,
#          'Tai': 3,
#          'duta': 1,
#          'bata': 11,
#          'Aauta': 3,
#          'select': 1,
#          'vane': 48,
#          'Quick': 1,
#          'charging': 1,
#          'Tyo': 17,
#          'maile': 9,
#          'nai': 50,
#          'garnu': 11,
#          'parne': 7,
#          'Gardau': 2,
#          'vayo': 26,
#          'Free': 1,
#          'maii': 1,
#          'Aani': 14,
#          'chaiyoo🤣🤣': 1,
#          'K': 77,
#          'Last': 2,
#          'thik': 12,
#          'Feature': 1,
#          'aautai': 1,
#          'here': 6,
#          'size': 1,
#          'thulo': 2,
#          'compare': 1,
#          'Ali': 3,
#          'farak': 1,
#          'aajha': 4,
#          'Euta': 3,
#          '4g': 1,
#          'arko': 3,
#          '5': 3,
#          'g': 1,
#          'tyo': 23,
#          'Thank': 3,
#          'u': 6,
#          'vandi': 2,
#          'vaneko': 3,
#          'thank': 1,
#          'you': 1,
#          'return': 2,
#          'hudai': 16,
#          'Clear': 1,
#          'xaina': 26,
#          'kehi': 23,
#          'bujhi': 2,
#          'J': 3,
#          'hos': 1,
#          'wala': 3,
#          'xq': 1,
#          'tyati': 2,
#          'Seen': 1,
#          'garyo': 2,
#          'vane,': 2,
#          'parxa': 5,
#          'Kin': 11,
#          'retur': 1,
#          'mageko': 1,
#          'Kam': 3,
#          'vayesi': 2,
#          'repl': 1,
#          'hudo': 1,
#          'rahex': 3,
#          'Sab': 4,
#          'manxe': 26,
#          'yastaii': 1,
#          'duniya': 5,
#          'jasto': 8,
#          'lago...': 1,
#          'Timi': 28,
#          'ka': 21,
#          'Aaile': 5,
#          'स्वार्थी': 1,
#          'भए': 1,
#          'र': 2,
#          '11': 1,
#          'baje': 7,
#          'garam': 4,
#          'kura': 29,
#          'ki': 35,
#          'a': 3,
#          'de': 1,
#          'reply': 16,
#          'Ho': 7,
#          'Special': 1,
#          'bala': 6,
#          'sathi': 13,
#          'sang': 11,
#          'garthe': 1,
#          'Ko': 16,
#          'Xa': 5,
#          'koii': 4,
#          'That': 1,
#          'confedential': 1,
#          'mildai': 4,
#          'Vanamla': 4,
#          'yau': 1,
#          'mobile': 8,
#          'Xaina': 7,
#          'Tasto': 5,
#          'aaile': 7,
#          'kina': 12,
#          'Aaba': 11,
#          'xito': 3,
#          'vani': 3,
#          'hal': 7,
#          'Hllo': 7,
#          'Hloo': 1,
#          'Voli': 12,
#          'kaha': 12,
#          'mela': 5,
#          'jane': 4,
#          'bchar': 1,
#          'Ghar': 13,
#          'Bidesh': 2,
#          'laiye': 1,
#          'lai': 56,
#          'darta': 1,
#          'garaunu': 1,
#          'Purnima': 1,
#          'heri': 2,
#          'dine': 1,
#          'Aja': 2,
#          'sayad': 2,
#          'feri': 3,
#          'purnima': 1,
#          'kaso': 5,
#          'timi': 13,
#          'tha': 29,
#          'hunu': 9,
#          'aja': 7,
#          'use': 2,
#          'hola': 21,
#          'Reply': 2,
#          'didanua': 1,
#          'tme': 26,
#          'malai': 25,
#          'vanxa': 5,
#          'chahi': 2,
#          'Kasto': 14,
#          'ayoo': 1,
#          'Tyasko': 1,
#          'check': 2,
#          'para': 2,
#          'Registre': 1,
#          'vako': 12,
#          'using': 1,
#          'imei': 1,
#          'number': 1,
#          'checking': 1,
#          'Kaha': 15,
#          'vago': 1,
#          '....': 4,
#          'Dunya': 1,
#          'hoina,': 1,
#          'Duniya': 1,
#          'dos': 3,
#          'dinxau': 3,
#          'Bujhi': 4,
#          'Kaslai': 5,
#          'diu': 1,
#          'vanna': 5,
#          'Kasari': 3,
#          ',': 7,
#          'zau': 1,
#          'Xau': 2,
#          'Aafai': 1,
#          'lai😂': 1,
#          'Kasri': 2,
#          'aafai': 4,
#          'https': 46,
#          'Tala': 1,
#          'link': 6,
#          'gayer': 1,
#          'IMEI': 1,
#          'NO.': 1,
#          'HALNE': 1,
#          'Ani': 2,
#          'kal': 4,
#          'k😔': 1,
#          'Bujhyauu': 1,
#          'Mero': 8,
#          'vagya': 1,
#          'kharab': 5,
#          'Bahut': 5,
#          'Yasma': 3,
#          'kunqi': 1,
#          'mandi': 1,
#          'foto': 1,
#          'gara': 23,
#          '??': 2,
#          'Click': 1,
#          'anii': 1,
#          'thaha': 7,
#          'Pauxauuu': 1,
#          'Mandi?': 1,
#          'page': 1,
#          'form': 1,
#          'rakhna': 1,
#          'You': 9,
#          'this': 9,
#          'null': 1,
#          'parxau': 1,
#          'rakhxau': 1,
#          'tyasmai': 1,
#          'hunxa🤣🤣': 1,
#          'xau,': 2,
#          'lagxa': 12,
#          'Tha,': 1,
#          'sode,': 1,
#          'natra': 2,
#          'sodhu': 1,
#          'Guess': 2,
#          'kaam': 4,
#          'gardi': 2,
#          'ma,': 1,
#          'Ag': 1,
#          'Kaile': 3,
#          'Khoi': 20,
#          'giriraj': 1,
#          'khabar': 6,
#          'uta': 2,
#          'tir': 2,
#          'harayau': 4,
#          'Kata': 11,
#          'kata': 6,
#          'vo': 3,
#          'Independent': 1,
#          'dekhayen': 1,
#          'Competation': 1,
#          '2': 12,
#          'bich': 1,
#          'matra': 4,
#          'independent': 1,
#          'tharai': 1,
#          'paxadi': 1,
#          'Timro': 16,
#          'bichar': 2,
#          'jite': 1,
#          'vote': 2,
#          'diye': 1,
#          'Sabai': 1,
#          'afano': 2,
#          'vision': 1,
#          'agenda': 1,
#          'le': 23,
#          'ako': 1,
#          'aba': 2,
#          'heram': 4,
#          'Kati': 12,
#          'baki': 4,
#          'x': 1,
#          'counting': 1,
#          'And': 1,
#          'chitwan': 3,
#          'update': 1,
#          'Tha': 7,
#          'bicahr': 1,
#          'jiteko': 1,
#          'gartye': 1,
#          'part': 1,
#          'Khan': 1,
#          'pauthe': 1,
#          'birgunj': 1,
#          'janu': 3,
#          'Lovi': 1,
#          'Vetnu': 1,
#          'jana': 5,
#          'Nai': 24,
#          'Ok': 15,
#          'Suitable': 1,
#          'time': 9,
#          'wait': 2,
#          'Vanu': 4,
#          'vanA,': 1,
#          'tasto': 4,
#          'basne': 4,
#          'khal': 1,
#          'xuina': 1,
#          'n': 2,
#          'basa': 2,
#          'Cll': 2,
#          'garu': 1,
#          'Tik': 4,
#          'vanoo': 1,
#          'bekar': 1,
#          'Lekhna': 1,
#          'jhyau': 1,
#          'exam🥺🥺': 1,
#          'Numerical': 1,
#          'gardau': 2,
#          'Call': 7,
#          'garxu': 8,
#          'ahile': 5,
#          '5min': 1,
#          'Kehi': 10,
#          'bises': 2,
#          'Genetic': 1,
#          'min': 1,
#          'Sathi': 3,
#          'padhi': 1,
#          'disturb': 5,
#          'Missed': 14,
#          'voice': 14,
#          'call': 21,
#          'u,': 1,
#          'buttimi': 1,
#          'kasari': 5,
#          'patlu': 1,
#          'Intelligent': 1,
#          'But': 7,
#          'motaxu': 1,
#          'Juoo': 1,
#          'motaye': 2,
#          'si': 2,
#          'sound': 2,
#          'motaooxa': 1,
#          'motaoodi': 2,
#          'kaile': 5,
#          'Jasto': 3,
#          'exam': 33,
#          'sakesi': 1,
#          'gara......': 1,
#          'Ahile': 4,
#          'gaye': 4,
#          'Huss': 4,
#          'Guddu': 2,
#          'herekai': 1,
#          'tastai': 5,
#          'Yasto': 11,
#          'open': 1,
#          'hacker': 1,
#          'hack': 1,
#          'garidin': 1,
#          'sakxa': 6,
#          'dekhya': 2,
#          'xaiii': 2,
#          'Sachai': 3,
#          'yasto': 14,
#          'Hoina': 2,
#          'Facebook': 4,
#          'video': 7,
#          'Exam': 17,
#          'timro': 6,
#          'Tmro': 6,
#          'hoin': 8,
#          'Padhne': 1,
#          'afu': 1,
#          'vanxau': 5,
#          'hyat': 1,
#          'Na': 7,
#          'padhe': 2,
#          'Kura': 4,
#          'cll': 10,
#          'typing': 3,
#          'jhau': 1,
#          'haiii': 3,
#          'Yati': 8,
#          'sama': 2,
#          'aalxi': 1,
#          'kin': 8,
#          'pathako': 3,
#          'junior': 2,
#          'aai': 5,
#          'sake': 14,
#          'hsi': 1,
#          'Pida': 1,
#          'buje': 1,
#          'ra🤣🤣': 1,
#          'tarkari': 4,
#          'oil': 1,
#          'khanxau': 1,
#          'Bujha': 1,
#          'afaii': 1,
#          'Kukhura': 1,
#          'Dukha': 1,
#          'dukkha': 1,
#          'bujhe': 3,
#          'patha': 3,
#          'forward': 2,
#          'gardinu': 1,
#          'Yatika': 1,
#          'experince': 1,
#          'kasri': 5,
#          'vayauuu': 1,
#          'Thanks': 1,
#          'dukha': 1,
#          'bujheko': 1,
#          'mq': 1,
#          'Ya': 1,
#          'ramri': 1,
#          'pelya': 1,
#          'senior': 1,
#          'pida': 1,
#          'deke': 1,
#          'Mainly': 1,
#          'Tme': 13,
#          'samjheko': 1,
#          'tyasto': 2,
#          'mnxe': 1,
#          'lagiraxu': 1,
#          'Tyati': 1,
#          'samma': 3,
#          'xuin': 1,
#          'oooo': 2,
#          'Jati': 1,
#          'man': 10,
#          'hloo': 1,
#          'vagyau': 2,
#          'Udi': 1,
#          'saki': 3,
#          'thye': 1,
#          'dance': 3,
#          'gari': 3,
#          'vhane,': 1,
#          'biswas': 5,
#          'vai': 12,
#          'jab': 2,
#          'lagane': 1,
#          'lu': 1,
#          'libistk🤣🤣🤣': 1,
#          'sachaii': 2,
#          'jhuto': 5,
#          'lagya': 2,
#          'kasailai': 3,
#          'pathaunu': 2,
#          'Saraswati': 1,
#          'vagwan': 2,
#          'aagadi': 4,
#          'banner': 1,
#          'rakhe': 1,
#          'geet': 1,
#          'gardai': 10,
#          'pathai': 2,
#          'bitikai': 3,
#          'google': 1,
#          'save🤣🤣': 1,
#          'arukai': 1,
#          'bujhenau': 1,
#          'Herna': 3,
#          'Viral': 1,
#          'garaoonu': 1,
#          'pare': 1,
#          'herna': 1,
#          'aru': 8,
#          'but': 13,
#          'viral': 2,
#          'garauna': 1,
#          'maan': 5,
#          'xain': 17,
#          'hala': 1,
#          'koi': 8,
#          'paye': 5,
#          'hudAIN': 1,
#          'N': 1,
#          'ramrai': 1,
#          'garaoodi': 1,
#          'tension': 1,
#          'lau': 1,
#          'Baru': 1,
#          'sulai': 2,
#          'dinxu': 1,
#          'VANYA': 1,
#          'j': 3,
#          'kaun': 2,
#          'he': 44,
#          'fir': 3,
#          'Dhaga': 1,
#          'Uslai': 1,
#          'k,': 1,
#          'mistake': 2,
#          'kaslia': 1,
#          'sab': 13,
#          'birse': 1,
#          'Then': 1,
#          'byee,': 1,
#          'vok': 2,
#          'sakyo': 6,
#          'lastaii': 1,
#          'khaoo': 1,
#          'khana': 5,
#          'Aadhi': 1,
#          'kaslai': 4,
#          'bahek': 2,
#          'gray': 1,
#          'viddeo': 1,
#          'tiktok': 2,
#          'bani': 1,
#          'bujhin': 2,
#          'aarko': 1,
#          'din': 18,
#          'vanu': 13,
#          'rose': 1,
#          'payau': 1,
#          'aja.....': 1,
#          'Diye': 1,
#          'po': 4,
#          'paunu': 2,
#          'bg': 8,
#          '9': 2,
#          'paxi': 8,
#          'graxu': 1,
#          'No,': 1,
#          'voli': 3,
#          'exam😟': 1,
#          'Kate': 1,
#          'dekher': 1,
#          'darayer': 1,
#          'pani': 9,
#          'deko': 2,
#          'ra,': 3,
#          'daraoonu': 1,
#          'paryo': 4,
#          'Same': 5,
#          'u🥰': 1,
#          'hamro': 5,
#          'culture': 1,
#          'hoina': 2,
#          '🥱🥱🥱🥱': 1,
#          'Best': 1,
#          'luck': 1,
#          'for': 2,
#          'today...': 1,
#          'Tasai': 1,
#          'Send': 2,
#          'Hernai': 1,
#          'unsent': 3,
#          'garyau': 2,
#          'Here': 2,
#          'noo': 4,
#          'ser': 2,
#          'agadi': 3,
#          'yehi': 1,
#          'chuha': 1,
#          'aye': 1,
#          'xan': 4,
#          'Gudiya': 2,
#          'as': 1,
#          'hai': 21,
#          'Arko': 1,
#          'Change': 1,
#          'vaxai': 1,
#          'nau': 5,
#          'kasto': 14,
#          'lagdai': 7,
#          'change': 2,
#          'Ye': 11,
#          'Pata': 3,
#          'nahi': 25,
#          'hat': 3,
#          'Name': 7,
#          'vandin': 2,
#          'ooo': 6,
#          'No': 7,
#          'patyako': 1,
#          'patya': 1,
#          'ha': 8,
#          'Maile': 5,
#          'padhna': 4,
#          'janau': 1,
#          'Parsi': 4,
#          'biochemistry': 1,
#          'ko😢': 1,
#          'I': 2,
#          "don't": 2,
#          'like': 2,
#          'likes': 1,
#          'cant': 1,
#          'avoid': 1,
#          'exam.....': 1,
#          'Dance': 2,
#          'Bachha': 1,
#          '73': 1,
#          '72': 1,
#          'dherrai': 1,
#          'innocent': 1,
#          'thiyau': 1,
#          'la...': 1,
#          'xu,': 1,
#          'Malai': 10,
#          'lager': 2,
#          '..': 16,
#          'garya': 6,
#          'Pathau': 1,
#          'Yastai': 2,
#          'jo': 7,
#          'screenshot': 2,
#          'rati': 2,
#          'vabe': 2,
#          'tye': 8,
#          'Smiley': 1,
#          'saurabh': 1,
#          'xa🤣': 1,
#          'chahiyo': 1,
#          'lake': 1,
#          'Tyatikaii': 1,
#          'Pet': 2,
#          'pooja': 1,
#          'Aali': 2,
#          'aali': 3,
#          'sajh': 2,
#          'xa🤣🤣': 1,
#          'Vaisako': 1,
#          'tala': 1,
#          'seen': 1,
#          'mathi': 1,
#          'vanished': 2,
#          'Screenshot': 1,
#          'pauxau': 1,
#          'xordau': 5,
#          'makai': 2,
#          'pakaoonu': 1,
#          'gru': 1,
#          'kam': 9,
#          'xw': 1,
#          'Tyatikai': 1,
#          'chinta': 1,
#          'liyer': 1,
#          'basya': 1,
#          'xay': 1,
#          'uo': 1,
#          'herdai': 1,
#          'hereko': 1,
#          'padhdai': 1,
#          'vaigo': 1,
#          '..yehi': 1,
#          'tmro': 4,
#          'garda': 3,
#          'gariyo,': 1,
#          'hath': 3,
#          'li': 1,
#          'start': 2,
#          '📢📢': 1,
#          'banako': 1,
#          'Yaslai': 1,
#          'word': 1,
#          'vetin': 1,
#          'Super': 1,
#          'excellent': 1,
#          'Khana': 6,
#          'khayoo': 1,
#          'Khuwaune': 1,
#          'kasle': 1,
#          'khuwauxa': 1,
#          'plan': 3,
#          'plan?': 1,
#          'day': 4,
#          'Field': 2,
#          'parne😂': 1,
#          'Bises': 1,
#          'kun': 2,
#          'ra?': 3,
#          'Tuesday': 1,
#          'Ramro': 4,
#          'sunday': 1,
#          'Monday': 1,
#          'birsya': 2,
#          'xainau': 1,
#          'Taso': 1,
#          'vye,': 1,
#          'Hotel': 1,
#          'jau': 2,
#          'na,': 4,
#          'serve': 1,
#          'garne': 6,
#          'khuwai': 1,
#          'dinxa': 2,
#          'Khaye': 1,
#          'afno': 1,
#          'khanay': 1,
#          'khayau': 2,
#          'naj': 1,
#          'vanya': 11,
#          'Baki': 1,
#          'khane': 3,
#          'Laz': 1,
#          'Lazy': 2,
#          'kha': 1,
#          'aau': 3,
#          'Afaii': 1,
#          'banayau': 2,
#          'Damj': 1,
#          'tara': 3,
#          'Bato': 1,
#          'Aaudai': 1,
#          'pathapoxau': 1,
#          'yati': 4,
#          'khoi': 4,
#          'Anand': 1,
#          'gareko': 6,
#          'chaldai': 3,
#          'chado': 1,
#          'Holi': 2,
#          'hunxau': 2,
#          '.Ghar': 1,
#          'auna': 2,
#          'aisakya': 1,
#          'security': 1,
#          'dekhauxa': 1,
#          'Code': 1,
#          'Can': 1,
#          'i': 2,
#          'today': 1,
#          'For': 1,
#          'past': 1,
#          'one': 1,
#          '🤣🤣🤣🤣😃😃': 1,
#          'Sachai🤣': 1,
#          'happy': 1,
#          'holi': 2,
#          'Engineer': 2,
#          'purai': 4,
#          'rup': 1,
#          'dhali': 1,
#          'ta🤣🤣🤣🤣': 1,
#          'kapal': 1,
#          'batdi': 1,
#          'tha🤣🤣': 1,
#          'khelenau': 1,
#          '1': 9,
#          ',2%': 1,
#          '🤣': 2,
#          'matrai': 9,
#          'Maan': 1,
#          'tatikai': 1,
#          'lagyo': 2,
#          'Sahi': 1,
#          'photo': 7,
#          'kheleko': 1,
#          'pic': 1,
#          'click': 1,
#          'Biswas': 2,
#          'k?': 2,
#          'Aur': 4,
#          'batau': 2,
#          'grxa': 1,
#          'Raa': 1,
#          'Wish': 1,
#          'gardeu': 3,
#          'Fever': 1,
#          'Ruga': 2,
#          'lage': 9,
#          'Kahile': 6,
#          'ghar': 13,
#          'ayau': 2,
#          '19': 1,
#          'kai': 4,
#          'Umm,': 5,
#          'bolxu': 2,
#          'pani😥😥': 1,
#          'niko': 2,
#          'bhako': 1,
#          'xaij': 1,
#          'raaa': 1,
#          'ruga': 2,
#          'varkhar': 1,
#          'days': 1,
#          'Aa': 1,
#          'xutti': 1,
#          'raa': 2,
#          'Bida': 1,
#          'months': 1,
#          'dekhi,': 1,
#          'routine': 1,
#          'aauxa': 1,
#          'Ooo': 1,
#          'tyaha': 1,
#          'freedom': 1,
#          'student': 1,
#          'union': 1,
#          '..purai': 1,
#          'nepal': 2,
#          'Sarkari': 1,
#          'cllg': 2,
#          'Aru': 4,
#          'no': 1,
#          'Bj': 1,
#          'Bi': 1,
#          'Ni': 4,
#          'hatar': 1,
#          'Chunab': 1,
#          'Katai': 2,
#          'Ki': 7,
#          'bhoj': 1,
#          'khuwaune': 1,
#          'pakaoo': 1,
#          'khauu': 1,
#          'Specail': 1,
#          'special': 2,
#          'Xod': 5,
#          'garamla': 1,
#          'Paxi': 1,
#          'Dubai': 1,
#          '17': 1,
#          'To': 2,
#          '12': 6,
#          'semester': 2,
#          'Total': 2,
#          'kati': 5,
#          'ota': 8,
#          'sub': 2,
#          'Jhau': 2,
#          'nose': 1,
#          'aauxa🤣🤣': 1,
#          'Misscall': 1,
#          'paisa': 4,
#          'katxa': 2,
#          'Data': 2,
#          'tyaso': 5,
#          'Net': 1,
#          'slow': 1,
#          'Paisa': 1,
#          'Mobile': 3,
#          'no.': 7,
#          'sutnu': 2,
#          'data': 1,
#          'pack': 2,
#          'kinidinxu': 1,
#          'fa': 1,
#          'Transfer': 1,
#          'Pardai': 1,
#          'Ta': 3,
#          'Tablet': 1,
#          'khaye': 1,
#          'nindra': 1,
#          'Yahi': 4,
#          'bat': 13,
#          'kinn': 1,
#          'milxa': 1,
#          'Yaspaxi': 1,
#          'jestha': 1,
#          'So': 2,
#          'Padhandas': 1,
#          'Tauko': 3,
#          'pain': 1,
#          'Hami': 4,
#          'engineer': 4,
#          'yastai': 2,
#          'Baishak': 1,
#          'samaatra': 1,
#          'gram': 1,
#          'hujxa': 2,
#          'Feri': 5,
#          'taso': 4,
#          'dau': 2,
#          'sute': 4,
#          'bytha': 1,
#          'poli': 1,
#          'yaha😥😥': 1,
#          'Poll': 1,
#          'dai': 2,
#          'kasta': 1,
#          'No.': 2,
#          'Deu': 1,
#          'Ekxin': 3,
#          'garer': 7,
#          'xodne': 1,
#          'Today': 1,
#          'is': 1,
#          'last': 2,
#          'Sachaiiii': 1,
#          'earth': 1,
#          'xodxu': 1,
#          'rA': 2,
#          'padha': 5,
#          'bela': 5,
#          '...ghar': 1,
#          'huda': 1,
#          'garhai': 1,
#          'hunxa..??': 1,
#          'Hellooo': 1,
#          'harayoo': 3,
#          'tyatikai': 1,
#          'Hii': 1,
#          'sako': 2,
#          'sodha': 1,
#          'Dimag': 1,
#          'Yastaii': 1,
#          'jindage': 1,
#          'vairaheko': 3,
#          'aram': 2,
#          'haiiii': 1,
#          'Top': 1,
#          'party': 3,
#          'deu': 11,
#          ...})

# %%
message_with_count=Counter(word_list).most_common(20)

# %%
#into dataframe
final_df=pd.DataFrame(message_with_count)

# %%
final_df.rename(columns={0:"Message",1:'Count'},inplace=True)

# %%
import seaborn as sns
#bar graph
plt.figure(figsize=(10,10))
plt.xticks(rotation='vertical')
sns.barplot(x=final_df['Message'],y=final_df['Count'])
plt.show()

# %%
df['month_num']=df['Date'].dt.month

# %%
timeline_df=df.groupby(['Year','month_num','month_name']).count()['message'].reset_index()

# %%
#join the name of month ansd yeae
time_list=[]
for i in range(timeline_df.shape[0]):
    time_list.append(timeline_df['month_name'][i]+"-"+str(timeline_df['Year'][i]))

# %%
timeline_df['time']=time_list

# %%
timeline_df
# Out:
#     Year  month_num month_name  message            time
# 0   2022          9  September       84  September-2022
# 1   2022         10    October       43    October-2022
# 2   2022         11   November       47   November-2022
# 3   2022         12   December        3   December-2022
# 4   2023          1    January        7    January-2023
# 5   2023          2   February      295   February-2023
# 6   2023          3      March      139      March-2023
# 7   2023          4      April       45      April-2023
# 8   2023          5        May      164        May-2023
# 9   2023          6       June       31       June-2023
# 10  2023          7       July      121       July-2023
# 11  2023          8     August       99     August-2023
# 12  2023          9  September      229  September-2023
# 13  2023         10    October      400    October-2023
# 14  2023         11   November      305   November-2023

# %%
#plot in grpah
plt.plot(timeline_df['time'],timeline_df['message'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df
# Out:
#                     Date                user     message  Year month_name  \
# 0    2022-09-28 21:21:00  Group_notification              2022  September
# 1    2022-09-28 20:23:00            Guddu...         Hlo  2022  September
# 2    2022-09-28 21:43:00           Khushilal         Hjr  2022  September
# 3    2022-09-28 21:43:00           Khushilal      Vannue  2022  September
# 4    2022-09-28 21:43:00           Khushilal           S  2022  September
# ...                  ...                 ...         ...   ...        ...
# 2007 2023-11-21 18:24:00           Khushilal  party chai  2023   November
# 2008 2023-11-21 18:26:00            Guddu...      Online  2023   November
# 2009 2023-11-21 18:26:00            Guddu...   Dhanyavad  2023   November
# 2010 2023-11-21 18:43:00           Khushilal   deu na ta  2023   November
# 2011 2023-11-21 20:04:00           Khushilal          ..  2023   November
#
#       day  Hour  Minutes  month_num
# 0      28    21       21          9
# 1      28    20       23          9
# 2      28    21       43          9
# 3      28    21       43          9
# 4      28    21       43          9
# ...   ...   ...      ...        ...
# 2007   21    18       24         11
# 2008   21    18       26         11
# 2009   21    18       26         11
# 2010   21    18       43         11
# 2011   21    20        4         11
#
# [2012 rows x 9 columns]

# %%
df['Date'].dt.day
# Out:
# 0       28
# 1       28
# 2       28
# 3       28
# 4       28
#         ..
# 2007    21
# 2008    21
# 2009    21
# 2010    21
# 2011    21
# Name: Date, Length: 2012, dtype: int64

# %%
df['only_date']=df['Date'].dt.date

# %%
daily_timeline=df.groupby(['only_date']).count()['message'].reset_index()

# %%
daily_timeline
# Out:
#       only_date  message
# 0    2022-09-28        5
# 1    2022-09-29       67
# 2    2022-09-30       12
# 3    2022-10-01        1
# 4    2022-10-04       34
# ..          ...      ...
# 138  2023-11-14        4
# 139  2023-11-15        5
# 140  2023-11-16        1
# 141  2023-11-17        1
# 142  2023-11-21       23
#
# [143 rows x 2 columns]

# %%
# Out:
# 0      2022-09-28
# 1      2022-09-29
# 2      2022-09-30
# 3      2022-10-01
# 4      2022-10-04
#           ...
# 138    2023-11-14
# 139    2023-11-15
# 140    2023-11-16
# 141    2023-11-17
# 142    2023-11-21
# Name: only_date, Length: 143, dtype: object

# %%
#plot in grpah
plt.figure(figsize=(10,10))
plt.plot(daily_timeline['only_date'],daily_timeline['message'])
# plt.xticks(rotation='vertical')
plt.show()
